# %%
# 확률적 경사하강

class SGD:
    def __init__(self, lr=0.01):
        self.lr = lr
        
    def update(self, params, grads):
        for key in params.keys():
            params[key] -= self.lr * grads[key]

# %%
# 모멘텀 옵티마이저

class Momentum:
    def __init__(self, lr=0.01, momentum=0.9):
        self.lr = lr
        self.momentum = momentum
        self.v = None
        
    def update(self, params, grads):
        if self.v is None:
            self.v = {}
            for key, val in params.items():
                self.v[key] = np.zeros_like(val)
            
        for key in params.keys():
            self.v[key] = self.momentum * self.v[key] - self.lr * grads[key]
            params[key] += self.v[key]

# %%
# AdaGrad 옵티마이저
# 학습률을 낮추는 방향

class AdaGrad:
    def __init__(self, lr=0.01):
        self.lr = lr
        self.h = None
        
    def update(self, params, grads):
        if self.h is None:
            self.h = {}
            
            for key, val in params.items():
                self.h[key] = np.zeros_like(val)
        
        for key in params.keys():
            self.h[key] += grads[key] * grads[key]
            params[key] -= self.lr * grads[key] / (np.sqrt(self.h[key]) + 1e-7)

# %%
# Adam 옵티마이저
# AdaGrad와 Momentum을 융합

class Adam:

    """Adam (http://arxiv.org/abs/1412.6980v8)"""

    def __init__(self, lr=0.001, beta1=0.9, beta2=0.999):
        self.lr = lr
        self.beta1 = beta1
        self.beta2 = beta2
        self.iter = 0
        self.m = None
        self.v = None
        
    def update(self, params, grads):
        if self.m is None:
            self.m, self.v = {}, {}
            for key, val in params.items():
                self.m[key] = np.zeros_like(val)
                self.v[key] = np.zeros_like(val)
        
        self.iter += 1
        lr_t  = self.lr * np.sqrt(1.0 - self.beta2**self.iter) / (1.0 - self.beta1**self.iter)         
        
        for key in params.keys():
            #self.m[key] = self.beta1*self.m[key] + (1-self.beta1)*grads[key]
            #self.v[key] = self.beta2*self.v[key] + (1-self.beta2)*(grads[key]**2)
            self.m[key] += (1 - self.beta1) * (grads[key] - self.m[key])
            self.v[key] += (1 - self.beta2) * (grads[key]**2 - self.v[key])
            
            params[key] -= lr_t * self.m[key] / (np.sqrt(self.v[key]) + 1e-7)
            
            #unbias_m += (1 - self.beta1) * (grads[key] - self.m[key]) # correct bias
            #unbisa_b += (1 - self.beta2) * (grads[key]*grads[key] - self.v[key]) # correct bias
            #params[key] += self.lr * unbias_m / (np.sqrt(unbisa_b) + 1e-7)

# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict
from common.optimizer import *


def f(x, y):
    return x**2 / 20.0 + y**2


def df(x, y):
    return x / 10.0, 2.0*y

init_pos = (-7.0, 2.0)
params = {}
params['x'], params['y'] = init_pos[0], init_pos[1]
grads = {}
grads['x'], grads['y'] = 0, 0


optimizers = OrderedDict()
optimizers["SGD"] = SGD(lr=0.95)
optimizers["Momentum"] = Momentum(lr=0.1)
optimizers["AdaGrad"] = AdaGrad(lr=1.5)
optimizers["Adam"] = Adam(lr=0.3)

idx = 1

for key in optimizers:
    optimizer = optimizers[key]
    x_history = []
    y_history = []
    params['x'], params['y'] = init_pos[0], init_pos[1]
    
    for i in range(30):
        x_history.append(params['x'])
        y_history.append(params['y'])
        
        grads['x'], grads['y'] = df(params['x'], params['y'])
        optimizer.update(params, grads)
    

    x = np.arange(-10, 10, 0.01)
    y = np.arange(-5, 5, 0.01)
    
    X, Y = np.meshgrid(x, y) 
    Z = f(X, Y)
    
    # 외곽선 단순화
    mask = Z > 7
    Z[mask] = 0
    
    # 그래프 그리기
    plt.subplot(2, 2, idx)
    idx += 1
    plt.plot(x_history, y_history, 'o-', color="red")
    plt.contour(X, Y, Z)
    plt.ylim(-10, 10)
    plt.xlim(-10, 10)
    plt.plot(0, 0, '+')
    #colorbar()
    #spring()
    plt.title(key)
    plt.xlabel("x")
    plt.ylabel("y")
    
plt.show()

# %%
# coding: utf-8
import os
import sys
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.util import smooth_curve
from common.multi_layer_net import MultiLayerNet
from common.optimizer import *


# 0. MNIST 데이터 읽기==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1. 실험용 설정==========
optimizers = {}
optimizers['SGD'] = SGD()
optimizers['Momentum'] = Momentum()
optimizers['AdaGrad'] = AdaGrad()
optimizers['Adam'] = Adam()
#optimizers['RMSprop'] = RMSprop()

networks = {}
train_loss = {}
for key in optimizers.keys():
    networks[key] = MultiLayerNet(
        input_size=784, hidden_size_list=[100, 100, 100, 100],
        output_size=10)
    train_loss[key] = []    


# 2. 훈련 시작==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in optimizers.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizers[key].update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        print( "===========" + "iteration:" + str(i) + "===========")
        for key in optimizers.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))


# 3. 그래프 그리기==========
markers = {"SGD": "o", "Momentum": "x", "AdaGrad": "s", "Adam": "D"}
x = np.arange(max_iterations)
for key in optimizers.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 1)
plt.legend()
plt.show()
# Out:
# ===========iteration:0===========
# SGD:2.4439297988455992
# Momentum:2.4551453833598256
# AdaGrad:2.1184206961102783
# Adam:2.2125991896536203
# ===========iteration:100===========
# SGD:1.4784461474414
# Momentum:0.5441594402009944
# AdaGrad:0.2881865936470956
# Adam:0.4453575994027781
# ===========iteration:200===========
# SGD:0.7222603984394241
# Momentum:0.22062963768127503
# AdaGrad:0.1159936571349588
# Adam:0.1687093433018091
# ===========iteration:300===========
# SGD:0.4598034550376412
# Momentum:0.14687911926298647
# AdaGrad:0.056350666125752555
# Adam:0.09925378857477271
# ===========iteration:400===========
# SGD:0.40325667115371566
# Momentum:0.1724926790541125
# AdaGrad:0.14640229027783144
# Adam:0.09731807225025273
# ===========iteration:500===========
# SGD:0.43884647791753406
# Momentum:0.2522396336894596
# AdaGrad:0.12084747097918343
# Adam:0.15863524604810048
# ===========iteration:600===========
# SGD:0.3816623223493212
# Momentum:0.14463413115371695
# AdaGrad:0.07535813509965358
# Adam:0.09854488853712537
# ===========iteration:700===========
# SGD:0.29815684049855823
# Momentum:0.15310288786189422
# AdaGrad:0.07264014911699888
# Adam:0.1299984447915703
# ===========iteration:800===========
# SGD:0.23736739410680724
# Momentum:0.05987808934719191
# AdaGrad:0.01987032400996902
# Adam:0.03032212465123064
# ===========iteration:900===========
# SGD:0.3117633211658351
# Momentum:0.22002739772773428
# AdaGrad:0.09480063818197872
# Adam:0.12509924002845538
# ===========iteration:1000===========
# SGD:0.23558224128206207
# Momentum:0.07188866731417043
# AdaGrad:0.044592259680719476
# Adam:0.06899909009292728
# ===========iteration:1100===========
# SGD:0.30518047248726726
# Momentum:0.18677191549244596
# AdaGrad:0.06514515207232648
# Adam:0.055787676635705545
# ===========iteration:1200===========
# SGD:0.25971242848671394
# Momentum:0.1385538220271494
# AdaGrad:0.039408180662358294
# Adam:0.08936094682695472
# ===========iteration:1300===========
# SGD:0.28107184692527376
# Momentum:0.13821714372110552
# AdaGrad:0.05328826578037399
# Adam:0.07670578172044162
# ===========iteration:1400===========
# SGD:0.2126903753238588
# Momentum:0.09213083019057827
# AdaGrad:0.040511650427377144
# Adam:0.05212863157215748
# ===========iteration:1500===========
# SGD:0.2258204019309491
# Momentum:0.05028257745892327
# AdaGrad:0.047787130145438485
# Adam:0.049837479642160065
# ===========iteration:1600===========
# SGD:0.1908516295873696
# Momentum:0.04715407421056051
# AdaGrad:0.019604177073300234
# Adam:0.03612114221458728
# ===========iteration:1700===========
# SGD:0.30405598681327217
# Momentum:0.0639500402266729
# AdaGrad:0.05196602765353457
# Adam:0.06081583337081557
# ===========iteration:1800===========
# SGD:0.2508963705590894
# Momentum:0.06360384826418278
# AdaGrad:0.06776045419526044
# Adam:0.02825114184056097
# ===========iteration:1900===========
# SGD:0.23704395913946166
# Momentum:0.06012939795419084
# AdaGrad:0.043185700026517435
# Adam:0.07645605442193848

# %%
# weight_init_activation_histogram.py
# 편차가 0일때

import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.random.randn(1000, 100)
node_num = 100
hidden_layer_size = 5
activations = {}

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i - 1]
        
    w = np.random.randn(node_num, node_num) * 1
    a = np.dot(x, w)
    z = sigmoid(a)
    activations[i] = z
    
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i + 1) + "-layer")
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# weight_init_activation_histogram.py
# 편차가 0.01일때

import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.random.randn(1000, 100)
node_num = 100
hidden_layer_size = 5
activations = {}

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i - 1]
        
    w = np.random.randn(node_num, node_num) * 0.01
    a = np.dot(x, w)
    z = sigmoid(a)
    activations[i] = z
    
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i + 1) + "-layer")
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %%
# weight_init_activation_histogram.py
# 초기 값을 Xavier를 사용한 경우

import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.random.randn(1000, 100)
node_num = 100
hidden_layer_size = 5
activations = {}

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i - 1]
        
    w = np.random.randn(node_num, node_num) / np.sqrt(node_num)
    a = np.dot(x, w)
    z = sigmoid(a)
    activations[i] = z
    
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i + 1) + "-layer")
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %%
# weight_init_activation_histogram.py 일부
# Relu의 경우
# He 초기값을 사용하는 경우
# Sigmoid와 tanh와 다르게 0과 1 사이의 중간지점이 곡선이 아니라 직선형일 때 사용

import numpy as np
import matplotlib.pyplot as plt

def relu(x):
    return np.maximum(0, x)

x = np.random.randn(1000, 100)
node_num = 100
hidden_layer_size = 5
activations = {}

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i - 1]
        
    w = np.random.randn(node_num, node_num) / np.sqrt(node_num) * np.sqrt(2)
    a = np.dot(x, w)
    z = relu(a)
    activations[i] = z
    
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i + 1) + "-layer")
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %%
# weight_init_compare.py

# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.util import smooth_curve
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD


# 0. MNIST 데이터 읽기==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1. 실험용 설정==========
weight_init_types = {'std=0.01': 0.01, 'Xavier': 'sigmoid', 'He': 'relu'}
optimizer = SGD(lr=0.01)

networks = {}
train_loss = {}
for key, weight_type in weight_init_types.items():
    networks[key] = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100],
                                  output_size=10, weight_init_std=weight_type)
    train_loss[key] = []


# 2. 훈련 시작==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in weight_init_types.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizer.update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        print("===========" + "iteration:" + str(i) + "===========")
        for key in weight_init_types.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))


# 3. 그래프 그리기==========
markers = {'std=0.01': 'o', 'Xavier': 's', 'He': 'D'}
x = np.arange(max_iterations)
for key in weight_init_types.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 2.5)
plt.legend()
plt.show()
# Out:
# ===========iteration:0===========
# std=0.01:2.302510639021591
# Xavier:2.30754657800563
# He:2.3543661109163017
# ===========iteration:100===========
# std=0.01:2.302320827556387
# Xavier:2.191063192922437
# He:1.5006230137651162
# ===========iteration:200===========
# std=0.01:2.302385200906484
# Xavier:1.9857071980407546
# He:0.6348147212595101
# ===========iteration:300===========
# std=0.01:2.300021441073307
# Xavier:1.5432744610144487
# He:0.5388919477350174
# ===========iteration:400===========
# std=0.01:2.297707168088575
# Xavier:1.0281192927520317
# He:0.457121672614897
# ===========iteration:500===========
# std=0.01:2.2986467177040355
# Xavier:0.8663394232162027
# He:0.47921831570987994
# ===========iteration:600===========
# std=0.01:2.3023694674142563
# Xavier:0.6694087178376287
# He:0.39859713150842957
# ===========iteration:700===========
# std=0.01:2.3011731402116093
# Xavier:0.5463283300305817
# He:0.3034965561465913
# ===========iteration:800===========
# std=0.01:2.306014445921561
# Xavier:0.5540170170220879
# He:0.31735558039935596
# ===========iteration:900===========
# std=0.01:2.3029633257034723
# Xavier:0.5943644378736432
# He:0.40929888001052456
# ===========iteration:1000===========
# std=0.01:2.3059012316986474
# Xavier:0.5039092098608684
# He:0.34225502402838415
# ===========iteration:1100===========
# std=0.01:2.2975330926119355
# Xavier:0.3495268949551432
# He:0.23127448066697925
# ===========iteration:1200===========
# std=0.01:2.299866014224799
# Xavier:0.35393784974829373
# He:0.22730691384407814
# ===========iteration:1300===========
# std=0.01:2.3000273080681617
# Xavier:0.31953734313103044
# He:0.23938907630971348
# ===========iteration:1400===========
# std=0.01:2.3002696689062345
# Xavier:0.24270808405694697
# He:0.16356694149280987
# ===========iteration:1500===========
# std=0.01:2.30015717816765
# Xavier:0.40660730061639133
# He:0.2393650989138073
# ===========iteration:1600===========
# std=0.01:2.3045924617224673
# Xavier:0.39018831212969585
# He:0.22858296903825523
# ===========iteration:1700===========
# std=0.01:2.30044773567871
# Xavier:0.4397347705564701
# He:0.2783238789235216
# ===========iteration:1800===========
# std=0.01:2.3038437529251876
# Xavier:0.4001245158518749
# He:0.29862716583843135
# ===========iteration:1900===========
# std=0.01:2.3011856847714363
# Xavier:0.2892084329850272
# He:0.21655353467243982

# %%
# batch_norm_test 
# 배치 정규화 테스트
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.optimizer import SGD, Adam

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 학습 데이터를 줄임
x_train = x_train[:1000]
t_train = t_train[:1000]

max_epochs = 20
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01


def __train(weight_init_std):
    bn_network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10, 
                                    weight_init_std=weight_init_std, use_batchnorm=True)
    network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10,
                                weight_init_std=weight_init_std)
    optimizer = SGD(lr=learning_rate)
    
    train_acc_list = []
    bn_train_acc_list = []
    
    iter_per_epoch = max(train_size / batch_size, 1)
    epoch_cnt = 0
    
    for i in range(1000000000):
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]
    
        for _network in (bn_network, network):
            grads = _network.gradient(x_batch, t_batch)
            optimizer.update(_network.params, grads)
    
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            bn_train_acc = bn_network.accuracy(x_train, t_train)
            train_acc_list.append(train_acc)
            bn_train_acc_list.append(bn_train_acc)
    
            print("epoch:" + str(epoch_cnt) + " | " + str(train_acc) + " - " + str(bn_train_acc))
    
            epoch_cnt += 1
            if epoch_cnt >= max_epochs:
                break
                
    return train_acc_list, bn_train_acc_list


# 그래프 그리기==========
weight_scale_list = np.logspace(0, -4, num=16)
x = np.arange(max_epochs)

for i, w in enumerate(weight_scale_list):
    print( "============== " + str(i+1) + "/16" + " ==============")
    train_acc_list, bn_train_acc_list = __train(w)
    
    plt.subplot(4,4,i+1)
    plt.title("W:" + str(w))
    if i == 15:
        plt.plot(x, bn_train_acc_list, label='Batch Normalization', markevery=2)
        plt.plot(x, train_acc_list, linestyle = "--", label='Normal(without BatchNorm)', markevery=2)
    else:
        plt.plot(x, bn_train_acc_list, markevery=2)
        plt.plot(x, train_acc_list, linestyle="--", markevery=2)

    plt.ylim(0, 1.0)
    if i % 4:
        plt.yticks([])
    else:
        plt.ylabel("accuracy")
    if i < 12:
        plt.xticks([])
    else:
        plt.xlabel("epochs")
    plt.legend(loc='lower right')
    
plt.show()
# Out:
# ============== 1/16 ==============
# epoch:0 | 0.097 - 0.104
# epoch:1 | 0.097 - 0.072
# epoch:2 | 0.097 - 0.101
# C:\Users\ksj31\OneDrive\바탕 화면\deep_learning\ch6\..\common\multi_layer_net_extend.py:104: RuntimeWarning: overflow encountered in square
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# C:\Users\ksj31\OneDrive\바탕 화면\deep_learning\ch6\..\common\multi_layer_net_extend.py:104: RuntimeWarning: invalid value encountered in double_scalars
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# C:\Users\ksj31\OneDrive\바탕 화면\deep_learning\ch6\..\common\functions.py:34: RuntimeWarning: invalid value encountered in subtract
#   x = x - np.max(x, axis=0)
# epoch:3 | 0.097 - 0.124
# epoch:4 | 0.097 - 0.157
# epoch:5 | 0.097 - 0.173
# epoch:6 | 0.097 - 0.192
# epoch:7 | 0.097 - 0.212
# epoch:8 | 0.097 - 0.226
# epoch:9 | 0.097 - 0.245
# epoch:10 | 0.097 - 0.261
# epoch:11 | 0.097 - 0.276
# epoch:12 | 0.097 - 0.291
# epoch:13 | 0.097 - 0.305
# epoch:14 | 0.097 - 0.334
# epoch:15 | 0.097 - 0.345
# epoch:16 | 0.097 - 0.369
# epoch:17 | 0.097 - 0.379
# epoch:18 | 0.097 - 0.396
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:19 | 0.097 - 0.402
# ============== 2/16 ==============
# epoch:0 | 0.099 - 0.106
# epoch:1 | 0.097 - 0.1
# epoch:2 | 0.097 - 0.09
# C:\Users\ksj31\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# epoch:3 | 0.097 - 0.125
# epoch:4 | 0.097 - 0.155
# epoch:5 | 0.097 - 0.174
# epoch:6 | 0.097 - 0.206
# epoch:7 | 0.097 - 0.224
# epoch:8 | 0.097 - 0.246
# epoch:9 | 0.097 - 0.272
# epoch:10 | 0.097 - 0.305
# epoch:11 | 0.097 - 0.322
# epoch:12 | 0.097 - 0.346
# epoch:13 | 0.097 - 0.358
# epoch:14 | 0.097 - 0.382
# epoch:15 | 0.097 - 0.392
# epoch:16 | 0.097 - 0.412
# epoch:17 | 0.097 - 0.422
# epoch:18 | 0.097 - 0.429
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:19 | 0.097 - 0.446
# ============== 3/16 ==============
# epoch:0 | 0.132 - 0.07
# epoch:1 | 0.353 - 0.092
# epoch:2 | 0.522 - 0.132
# epoch:3 | 0.582 - 0.17
# epoch:4 | 0.668 - 0.209
# epoch:5 | 0.714 - 0.239
# epoch:6 | 0.772 - 0.269
# epoch:7 | 0.801 - 0.304
# epoch:8 | 0.839 - 0.331
# epoch:9 | 0.869 - 0.363
# epoch:10 | 0.898 - 0.392
# epoch:11 | 0.916 - 0.425
# epoch:12 | 0.923 - 0.447
# epoch:13 | 0.95 - 0.465
# epoch:14 | 0.944 - 0.5
# epoch:15 | 0.963 - 0.517
# epoch:16 | 0.973 - 0.544
# epoch:17 | 0.978 - 0.563
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:18 | 0.979 - 0.583
# epoch:19 | 0.984 - 0.599
# ============== 4/16 ==============
# epoch:0 | 0.103 - 0.124
# epoch:1 | 0.216 - 0.16
# epoch:2 | 0.342 - 0.233
# epoch:3 | 0.454 - 0.309
# epoch:4 | 0.512 - 0.37
# epoch:5 | 0.553 - 0.422
# epoch:6 | 0.623 - 0.469
# epoch:7 | 0.656 - 0.522
# epoch:8 | 0.67 - 0.57
# epoch:9 | 0.72 - 0.61
# epoch:10 | 0.733 - 0.644
# epoch:11 | 0.752 - 0.684
# epoch:12 | 0.776 - 0.695
# epoch:13 | 0.78 - 0.719
# epoch:14 | 0.8 - 0.735
# epoch:15 | 0.817 - 0.759
# epoch:16 | 0.83 - 0.78
# epoch:17 | 0.818 - 0.788
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:18 | 0.852 - 0.797
# epoch:19 | 0.854 - 0.807
# ============== 5/16 ==============
# epoch:0 | 0.117 - 0.132
# epoch:1 | 0.12 - 0.137
# epoch:2 | 0.122 - 0.264
# epoch:3 | 0.122 - 0.422
# epoch:4 | 0.123 - 0.484
# epoch:5 | 0.122 - 0.577
# epoch:6 | 0.128 - 0.633
# epoch:7 | 0.131 - 0.673
# epoch:8 | 0.135 - 0.704
# epoch:9 | 0.145 - 0.728
# epoch:10 | 0.149 - 0.744
# epoch:11 | 0.151 - 0.762
# epoch:12 | 0.155 - 0.781
# epoch:13 | 0.165 - 0.8
# epoch:14 | 0.174 - 0.813
# epoch:15 | 0.173 - 0.834
# epoch:16 | 0.173 - 0.842
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:17 | 0.191 - 0.852
# epoch:18 | 0.194 - 0.87
# epoch:19 | 0.206 - 0.884
# ============== 6/16 ==============
# epoch:0 | 0.153 - 0.104
# epoch:1 | 0.143 - 0.174
# epoch:2 | 0.145 - 0.39
# epoch:3 | 0.117 - 0.57
# epoch:4 | 0.144 - 0.654
# epoch:5 | 0.138 - 0.722
# epoch:6 | 0.133 - 0.75
# epoch:7 | 0.122 - 0.771
# epoch:8 | 0.117 - 0.798
# epoch:9 | 0.116 - 0.823
# epoch:10 | 0.116 - 0.848
# epoch:11 | 0.116 - 0.858
# epoch:12 | 0.116 - 0.873
# epoch:13 | 0.154 - 0.892
# epoch:14 | 0.148 - 0.906
# epoch:15 | 0.182 - 0.913
# epoch:16 | 0.158 - 0.92
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:17 | 0.188 - 0.93
# epoch:18 | 0.133 - 0.935
# epoch:19 | 0.119 - 0.944
# ============== 7/16 ==============
# epoch:0 | 0.117 - 0.107
# epoch:1 | 0.136 - 0.204
# epoch:2 | 0.105 - 0.58
# epoch:3 | 0.116 - 0.707
# epoch:4 | 0.116 - 0.751
# epoch:5 | 0.116 - 0.787
# epoch:6 | 0.117 - 0.813
# epoch:7 | 0.117 - 0.855
# epoch:8 | 0.117 - 0.874
# epoch:9 | 0.117 - 0.891
# epoch:10 | 0.117 - 0.915
# epoch:11 | 0.117 - 0.93
# epoch:12 | 0.117 - 0.94
# epoch:13 | 0.117 - 0.954
# epoch:14 | 0.117 - 0.963
# epoch:15 | 0.117 - 0.971
# epoch:16 | 0.117 - 0.973
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:17 | 0.117 - 0.977
# epoch:18 | 0.117 - 0.984
# epoch:19 | 0.117 - 0.985
# ============== 8/16 ==============
# epoch:0 | 0.093 - 0.109
# epoch:1 | 0.099 - 0.398
# epoch:2 | 0.116 - 0.711
# epoch:3 | 0.116 - 0.815
# epoch:4 | 0.116 - 0.866
# epoch:5 | 0.116 - 0.897
# epoch:6 | 0.116 - 0.928
# epoch:7 | 0.116 - 0.947
# epoch:8 | 0.116 - 0.957
# epoch:9 | 0.116 - 0.968
# epoch:10 | 0.116 - 0.979
# epoch:11 | 0.116 - 0.987
# epoch:12 | 0.116 - 0.99
# epoch:13 | 0.116 - 0.997
# epoch:14 | 0.116 - 1.0
# epoch:15 | 0.116 - 0.999
# epoch:16 | 0.116 - 0.999
# epoch:17 | 0.116 - 1.0
# epoch:18 | 0.116 - 1.0
# epoch:19 | 0.116 - 1.0
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ============== 9/16 ==============
# epoch:0 | 0.116 - 0.126
# epoch:1 | 0.116 - 0.314
# epoch:2 | 0.116 - 0.724
# epoch:3 | 0.116 - 0.784
# epoch:4 | 0.116 - 0.852
# epoch:5 | 0.116 - 0.912
# epoch:6 | 0.116 - 0.955
# epoch:7 | 0.117 - 0.975
# epoch:8 | 0.116 - 0.984
# epoch:9 | 0.116 - 0.991
# epoch:10 | 0.116 - 0.993
# epoch:11 | 0.116 - 0.996
# epoch:12 | 0.116 - 0.998
# epoch:13 | 0.116 - 0.995
# epoch:14 | 0.116 - 0.997
# epoch:15 | 0.116 - 0.998
# epoch:16 | 0.116 - 0.998
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:17 | 0.116 - 0.998
# epoch:18 | 0.116 - 0.998
# epoch:19 | 0.117 - 0.999
# ============== 10/16 ==============
# epoch:0 | 0.117 - 0.218
# epoch:1 | 0.094 - 0.59
# epoch:2 | 0.105 - 0.608
# epoch:3 | 0.117 - 0.766
# epoch:4 | 0.117 - 0.778
# epoch:5 | 0.117 - 0.777
# epoch:6 | 0.117 - 0.802
# epoch:7 | 0.117 - 0.846
# epoch:8 | 0.117 - 0.878
# epoch:9 | 0.117 - 0.894
# epoch:10 | 0.117 - 0.871
# epoch:11 | 0.116 - 0.899
# epoch:12 | 0.116 - 0.891
# epoch:13 | 0.116 - 0.98
# epoch:14 | 0.116 - 0.982
# epoch:15 | 0.116 - 0.992
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:16 | 0.116 - 0.993
# epoch:17 | 0.116 - 0.994
# epoch:18 | 0.116 - 0.993
# epoch:19 | 0.116 - 0.997
# ============== 11/16 ==============
# epoch:0 | 0.1 - 0.161
# epoch:1 | 0.117 - 0.56
# epoch:2 | 0.117 - 0.771
# epoch:3 | 0.117 - 0.777
# epoch:4 | 0.117 - 0.909
# epoch:5 | 0.117 - 0.921
# epoch:6 | 0.117 - 0.893
# epoch:7 | 0.117 - 0.962
# epoch:8 | 0.117 - 0.956
# epoch:9 | 0.117 - 0.955
# epoch:10 | 0.117 - 0.977
# epoch:11 | 0.117 - 0.987
# epoch:12 | 0.117 - 0.991
# epoch:13 | 0.117 - 0.986
# epoch:14 | 0.117 - 0.984
# epoch:15 | 0.117 - 0.982
# epoch:16 | 0.117 - 0.988
# epoch:17 | 0.117 - 0.978
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:18 | 0.117 - 0.993
# epoch:19 | 0.117 - 0.993
# ============== 12/16 ==============
# epoch:0 | 0.093 - 0.142
# epoch:1 | 0.116 - 0.426
# epoch:2 | 0.116 - 0.451
# epoch:3 | 0.117 - 0.584
# epoch:4 | 0.117 - 0.401
# epoch:5 | 0.117 - 0.602
# epoch:6 | 0.117 - 0.688
# epoch:7 | 0.117 - 0.705
# epoch:8 | 0.117 - 0.705
# epoch:9 | 0.117 - 0.71
# epoch:10 | 0.117 - 0.772
# epoch:11 | 0.117 - 0.787
# epoch:12 | 0.117 - 0.76
# epoch:13 | 0.117 - 0.801
# epoch:14 | 0.117 - 0.742
# epoch:15 | 0.117 - 0.748
# epoch:16 | 0.117 - 0.728
# epoch:17 | 0.117 - 0.75
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:18 | 0.117 - 0.812
# epoch:19 | 0.117 - 0.813
# ============== 13/16 ==============
# epoch:0 | 0.116 - 0.173
# epoch:1 | 0.117 - 0.446
# epoch:2 | 0.116 - 0.488
# epoch:3 | 0.116 - 0.569
# epoch:4 | 0.117 - 0.58
# epoch:5 | 0.117 - 0.588
# epoch:6 | 0.117 - 0.589
# epoch:7 | 0.117 - 0.611
# epoch:8 | 0.117 - 0.684
# epoch:9 | 0.117 - 0.669
# epoch:10 | 0.117 - 0.695
# epoch:11 | 0.117 - 0.647
# epoch:12 | 0.117 - 0.754
# epoch:13 | 0.117 - 0.654
# epoch:14 | 0.116 - 0.776
# epoch:15 | 0.116 - 0.791
# epoch:16 | 0.117 - 0.776
# epoch:17 | 0.117 - 0.789
# epoch:18 | 0.117 - 0.799
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:19 | 0.117 - 0.805
# ============== 14/16 ==============
# epoch:0 | 0.094 - 0.125
# epoch:1 | 0.099 - 0.331
# epoch:2 | 0.117 - 0.44
# epoch:3 | 0.099 - 0.459
# epoch:4 | 0.117 - 0.455
# epoch:5 | 0.117 - 0.505
# epoch:6 | 0.117 - 0.505
# epoch:7 | 0.105 - 0.488
# epoch:8 | 0.117 - 0.516
# epoch:9 | 0.117 - 0.587
# epoch:10 | 0.117 - 0.593
# epoch:11 | 0.117 - 0.652
# epoch:12 | 0.117 - 0.691
# epoch:13 | 0.117 - 0.701
# epoch:14 | 0.117 - 0.675
# epoch:15 | 0.117 - 0.698
# epoch:16 | 0.117 - 0.799
# epoch:17 | 0.117 - 0.802
# epoch:18 | 0.117 - 0.734
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:19 | 0.116 - 0.79
# ============== 15/16 ==============
# epoch:0 | 0.117 - 0.097
# epoch:1 | 0.117 - 0.317
# epoch:2 | 0.117 - 0.322
# epoch:3 | 0.117 - 0.375
# epoch:4 | 0.117 - 0.425
# epoch:5 | 0.117 - 0.424
# epoch:6 | 0.117 - 0.424
# epoch:7 | 0.117 - 0.421
# epoch:8 | 0.117 - 0.43
# epoch:9 | 0.117 - 0.432
# epoch:10 | 0.117 - 0.432
# epoch:11 | 0.117 - 0.432
# epoch:12 | 0.117 - 0.432
# epoch:13 | 0.117 - 0.432
# epoch:14 | 0.117 - 0.432
# epoch:15 | 0.117 - 0.431
# epoch:16 | 0.117 - 0.432
# epoch:17 | 0.117 - 0.432
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# epoch:18 | 0.117 - 0.431
# epoch:19 | 0.117 - 0.432
# ============== 16/16 ==============
# epoch:0 | 0.1 - 0.174
# epoch:1 | 0.116 - 0.27
# epoch:2 | 0.116 - 0.439
# epoch:3 | 0.116 - 0.491
# epoch:4 | 0.116 - 0.489
# epoch:5 | 0.116 - 0.507
# epoch:6 | 0.116 - 0.517
# epoch:7 | 0.117 - 0.514
# epoch:8 | 0.117 - 0.519
# epoch:9 | 0.117 - 0.522
# epoch:10 | 0.117 - 0.512
# epoch:11 | 0.117 - 0.521
# epoch:12 | 0.117 - 0.523
# epoch:13 | 0.117 - 0.523
# epoch:14 | 0.117 - 0.524
# epoch:15 | 0.117 - 0.523
# epoch:16 | 0.116 - 0.524
# epoch:17 | 0.116 - 0.512
# epoch:18 | 0.116 - 0.525
# epoch:19 | 0.117 - 0.613

# %%
# 오버피팅 예시
# 강제로 오버피팅이 일어나는 모델 생성
# overfit_weight_decay.py
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

network = MultiLayerNet(input_size=784, hidden_size_list=[100,100,100,100,100,100], output_size = 10)
optimizer = SGD(lr=0.01)
max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)
    
    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)
        
        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break

markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()

# %%
# coding: utf-8
# overfit_weight_decay.py

import os
import sys

sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（가중치 감쇠） 설정 =======================
#weight_decay_lambda = 0 # weight decay를 사용하지 않을 경우
weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01) # 학습률이 0.01인 SGD로 매개변수 갱신

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.1, test acc:0.0761
# epoch:1, train acc:0.1, test acc:0.0782
# epoch:2, train acc:0.11, test acc:0.0863
# epoch:3, train acc:0.13333333333333333, test acc:0.1057
# epoch:4, train acc:0.15333333333333332, test acc:0.1227
# epoch:5, train acc:0.18, test acc:0.1385
# epoch:6, train acc:0.19666666666666666, test acc:0.1592
# epoch:7, train acc:0.21333333333333335, test acc:0.1808
# epoch:8, train acc:0.24, test acc:0.2006
# epoch:9, train acc:0.25666666666666665, test acc:0.2135
# epoch:10, train acc:0.2833333333333333, test acc:0.2285
# epoch:11, train acc:0.31666666666666665, test acc:0.24
# epoch:12, train acc:0.3566666666666667, test acc:0.2528
# epoch:13, train acc:0.38666666666666666, test acc:0.2679
# epoch:14, train acc:0.4066666666666667, test acc:0.282
# epoch:15, train acc:0.44, test acc:0.2905
# epoch:16, train acc:0.46, test acc:0.3033
# epoch:17, train acc:0.49666666666666665, test acc:0.3088
# epoch:18, train acc:0.49333333333333335, test acc:0.3185
# epoch:19, train acc:0.49333333333333335, test acc:0.3215
# epoch:20, train acc:0.5066666666666667, test acc:0.3333
# epoch:21, train acc:0.5266666666666666, test acc:0.3474
# epoch:22, train acc:0.5233333333333333, test acc:0.3612
# epoch:23, train acc:0.55, test acc:0.3664
# epoch:24, train acc:0.55, test acc:0.3659
# epoch:25, train acc:0.54, test acc:0.3687
# epoch:26, train acc:0.5466666666666666, test acc:0.3647
# epoch:27, train acc:0.5466666666666666, test acc:0.3685
# epoch:28, train acc:0.5466666666666666, test acc:0.3744
# epoch:29, train acc:0.5466666666666666, test acc:0.3798
# epoch:30, train acc:0.56, test acc:0.3933
# epoch:31, train acc:0.5566666666666666, test acc:0.4031
# epoch:32, train acc:0.5666666666666667, test acc:0.4107
# epoch:33, train acc:0.5733333333333334, test acc:0.4184
# epoch:34, train acc:0.57, test acc:0.415
# epoch:35, train acc:0.5633333333333334, test acc:0.4093
# epoch:36, train acc:0.5633333333333334, test acc:0.4289
# epoch:37, train acc:0.5666666666666667, test acc:0.435
# epoch:38, train acc:0.57, test acc:0.4485
# epoch:39, train acc:0.58, test acc:0.4539
# epoch:40, train acc:0.58, test acc:0.4539
# epoch:41, train acc:0.5833333333333334, test acc:0.4583
# epoch:42, train acc:0.58, test acc:0.4569
# epoch:43, train acc:0.59, test acc:0.4641
# epoch:44, train acc:0.59, test acc:0.4721
# epoch:45, train acc:0.5966666666666667, test acc:0.4796
# epoch:46, train acc:0.6033333333333334, test acc:0.4836
# epoch:47, train acc:0.6066666666666667, test acc:0.4817
# epoch:48, train acc:0.6166666666666667, test acc:0.4942
# epoch:49, train acc:0.62, test acc:0.4949
# epoch:50, train acc:0.62, test acc:0.5014
# epoch:51, train acc:0.64, test acc:0.5076
# epoch:52, train acc:0.6466666666666666, test acc:0.509
# epoch:53, train acc:0.66, test acc:0.5117
# epoch:54, train acc:0.67, test acc:0.5172
# epoch:55, train acc:0.6733333333333333, test acc:0.5193
# epoch:56, train acc:0.67, test acc:0.5218
# epoch:57, train acc:0.6733333333333333, test acc:0.5245
# epoch:58, train acc:0.6733333333333333, test acc:0.5309
# epoch:59, train acc:0.6966666666666667, test acc:0.5364
# epoch:60, train acc:0.6866666666666666, test acc:0.5373
# epoch:61, train acc:0.6866666666666666, test acc:0.5405
# epoch:62, train acc:0.7033333333333334, test acc:0.547
# epoch:63, train acc:0.72, test acc:0.5504
# epoch:64, train acc:0.7233333333333334, test acc:0.554
# epoch:65, train acc:0.6933333333333334, test acc:0.549
# epoch:66, train acc:0.74, test acc:0.5719
# epoch:67, train acc:0.7333333333333333, test acc:0.5688
# epoch:68, train acc:0.75, test acc:0.5685
# epoch:69, train acc:0.76, test acc:0.5827
# epoch:70, train acc:0.7866666666666666, test acc:0.5873
# epoch:71, train acc:0.7766666666666666, test acc:0.591
# epoch:72, train acc:0.77, test acc:0.5946
# epoch:73, train acc:0.7866666666666666, test acc:0.6039
# epoch:74, train acc:0.79, test acc:0.5993
# epoch:75, train acc:0.7933333333333333, test acc:0.6072
# epoch:76, train acc:0.7866666666666666, test acc:0.6138
# epoch:77, train acc:0.8, test acc:0.6331
# epoch:78, train acc:0.8133333333333334, test acc:0.6159
# epoch:79, train acc:0.8066666666666666, test acc:0.6113
# epoch:80, train acc:0.8, test acc:0.6219
# epoch:81, train acc:0.8133333333333334, test acc:0.6296
# epoch:82, train acc:0.8033333333333333, test acc:0.626
# epoch:83, train acc:0.8233333333333334, test acc:0.6318
# epoch:84, train acc:0.83, test acc:0.6558
# epoch:85, train acc:0.83, test acc:0.6509
# epoch:86, train acc:0.8166666666666667, test acc:0.6319
# epoch:87, train acc:0.8233333333333334, test acc:0.6405
# epoch:88, train acc:0.8266666666666667, test acc:0.6427
# epoch:89, train acc:0.8233333333333334, test acc:0.6307
# epoch:90, train acc:0.8266666666666667, test acc:0.6432
# epoch:91, train acc:0.8233333333333334, test acc:0.6534
# epoch:92, train acc:0.8333333333333334, test acc:0.6561
# epoch:93, train acc:0.8266666666666667, test acc:0.6529
# epoch:94, train acc:0.8333333333333334, test acc:0.6644
# epoch:95, train acc:0.8266666666666667, test acc:0.6615
# epoch:96, train acc:0.83, test acc:0.6689
# epoch:97, train acc:0.83, test acc:0.6605
# epoch:98, train acc:0.8366666666666667, test acc:0.6755
# epoch:99, train acc:0.8366666666666667, test acc:0.6699
# epoch:100, train acc:0.8433333333333334, test acc:0.6738
# epoch:101, train acc:0.8366666666666667, test acc:0.6737
# epoch:102, train acc:0.8433333333333334, test acc:0.6762
# epoch:103, train acc:0.84, test acc:0.6678
# epoch:104, train acc:0.8466666666666667, test acc:0.6815
# epoch:105, train acc:0.84, test acc:0.6703
# epoch:106, train acc:0.85, test acc:0.6743
# epoch:107, train acc:0.85, test acc:0.6854
# epoch:108, train acc:0.85, test acc:0.6727
# epoch:109, train acc:0.85, test acc:0.6752
# epoch:110, train acc:0.8433333333333334, test acc:0.6805
# epoch:111, train acc:0.8466666666666667, test acc:0.6904
# epoch:112, train acc:0.8466666666666667, test acc:0.6874
# epoch:113, train acc:0.85, test acc:0.6788
# epoch:114, train acc:0.8566666666666667, test acc:0.6836
# epoch:115, train acc:0.8633333333333333, test acc:0.6906
# epoch:116, train acc:0.85, test acc:0.6868
# epoch:117, train acc:0.86, test acc:0.6772
# epoch:118, train acc:0.8433333333333334, test acc:0.6807
# epoch:119, train acc:0.85, test acc:0.6832
# epoch:120, train acc:0.8433333333333334, test acc:0.6872
# epoch:121, train acc:0.85, test acc:0.694
# epoch:122, train acc:0.8466666666666667, test acc:0.6869
# epoch:123, train acc:0.86, test acc:0.687
# epoch:124, train acc:0.8733333333333333, test acc:0.6896
# epoch:125, train acc:0.87, test acc:0.6929
# epoch:126, train acc:0.87, test acc:0.6923
# epoch:127, train acc:0.8666666666666667, test acc:0.6952
# epoch:128, train acc:0.88, test acc:0.6919
# epoch:129, train acc:0.86, test acc:0.691
# epoch:130, train acc:0.87, test acc:0.6985
# epoch:131, train acc:0.8733333333333333, test acc:0.7034
# epoch:132, train acc:0.8666666666666667, test acc:0.6994
# epoch:133, train acc:0.8566666666666667, test acc:0.6912
# epoch:134, train acc:0.8733333333333333, test acc:0.6977
# epoch:135, train acc:0.8733333333333333, test acc:0.7005
# epoch:136, train acc:0.87, test acc:0.7041
# epoch:137, train acc:0.8633333333333333, test acc:0.7017
# epoch:138, train acc:0.84, test acc:0.6961
# epoch:139, train acc:0.88, test acc:0.7023
# epoch:140, train acc:0.8666666666666667, test acc:0.7063
# epoch:141, train acc:0.8733333333333333, test acc:0.7083
# epoch:142, train acc:0.8733333333333333, test acc:0.7112
# epoch:143, train acc:0.88, test acc:0.7108
# epoch:144, train acc:0.88, test acc:0.7075
# epoch:145, train acc:0.8633333333333333, test acc:0.7011
# epoch:146, train acc:0.8533333333333334, test acc:0.7008
# epoch:147, train acc:0.8733333333333333, test acc:0.6933
# epoch:148, train acc:0.8733333333333333, test acc:0.6969
# epoch:149, train acc:0.8833333333333333, test acc:0.7036
# epoch:150, train acc:0.8833333333333333, test acc:0.7079
# epoch:151, train acc:0.8833333333333333, test acc:0.7103
# epoch:152, train acc:0.8833333333333333, test acc:0.7048
# epoch:153, train acc:0.8833333333333333, test acc:0.7018
# epoch:154, train acc:0.88, test acc:0.7116
# epoch:155, train acc:0.8733333333333333, test acc:0.7026
# epoch:156, train acc:0.8833333333333333, test acc:0.7046
# epoch:157, train acc:0.8766666666666667, test acc:0.7073
# epoch:158, train acc:0.8866666666666667, test acc:0.7113
# epoch:159, train acc:0.8866666666666667, test acc:0.7117
# epoch:160, train acc:0.8733333333333333, test acc:0.7019
# epoch:161, train acc:0.87, test acc:0.7043
# epoch:162, train acc:0.8666666666666667, test acc:0.7057
# epoch:163, train acc:0.8866666666666667, test acc:0.7086
# epoch:164, train acc:0.8766666666666667, test acc:0.7018
# epoch:165, train acc:0.8866666666666667, test acc:0.7077
# epoch:166, train acc:0.8966666666666666, test acc:0.7065
# epoch:167, train acc:0.89, test acc:0.7123
# epoch:168, train acc:0.8966666666666666, test acc:0.709
# epoch:169, train acc:0.88, test acc:0.7079
# epoch:170, train acc:0.8733333333333333, test acc:0.7103
# epoch:171, train acc:0.8933333333333333, test acc:0.7104
# epoch:172, train acc:0.89, test acc:0.7101
# epoch:173, train acc:0.89, test acc:0.7108
# epoch:174, train acc:0.8833333333333333, test acc:0.707
# epoch:175, train acc:0.89, test acc:0.7061
# epoch:176, train acc:0.8933333333333333, test acc:0.7049
# epoch:177, train acc:0.89, test acc:0.7152
# epoch:178, train acc:0.8866666666666667, test acc:0.7145
# epoch:179, train acc:0.8933333333333333, test acc:0.7116
# epoch:180, train acc:0.8966666666666666, test acc:0.7139
# epoch:181, train acc:0.8766666666666667, test acc:0.7081
# epoch:182, train acc:0.8833333333333333, test acc:0.7129
# epoch:183, train acc:0.8966666666666666, test acc:0.7115
# epoch:184, train acc:0.8866666666666667, test acc:0.7106
# epoch:185, train acc:0.8933333333333333, test acc:0.7142
# epoch:186, train acc:0.89, test acc:0.7114
# epoch:187, train acc:0.8666666666666667, test acc:0.7095
# epoch:188, train acc:0.88, test acc:0.7089
# epoch:189, train acc:0.89, test acc:0.7083
# epoch:190, train acc:0.8866666666666667, test acc:0.7153
# epoch:191, train acc:0.89, test acc:0.7071
# epoch:192, train acc:0.86, test acc:0.7072
# epoch:193, train acc:0.8866666666666667, test acc:0.7091
# epoch:194, train acc:0.89, test acc:0.71
# epoch:195, train acc:0.8866666666666667, test acc:0.7159
# epoch:196, train acc:0.9, test acc:0.7191
# epoch:197, train acc:0.9, test acc:0.7154
# epoch:198, train acc:0.8966666666666666, test acc:0.7099
# epoch:199, train acc:0.89, test acc:0.7071
# epoch:200, train acc:0.8966666666666666, test acc:0.7076

# %%
# dropout 드롭아웃
#체이너Chainer 프레임워크(http://chainer.org/)

class Dropout:
    def __init__(self, dropout_ratio=0.5):
        self.dropout_ratio = dropout_ratio
        self.mask = None
        
    def forward(self, x, train_flg=True):
        if train_flg:
            self.mask = np.random.rand(*x.shape) > self.dropout_ratio
            return x * self.mask
        else:
            return x * (1.0 - self.dropout_ratio)
        
    def backward(self, dout):
        return dout * self.mask

# %%
# coding: utf-8
# overfit_dropout.py

import os
import sys
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# 드롭아웃 사용 유무와 비울 설정 ========================
use_dropout = True  # 드롭아웃을 쓰지 않을 때는 False
dropout_ratio = 0.2
# ====================================================

network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                              output_size=10, use_dropout=use_dropout, dropout_ration=dropout_ratio)
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=301, mini_batch_size=100,
                  optimizer='sgd', optimizer_param={'lr': 0.01}, verbose=True)
trainer.train()

train_acc_list, test_acc_list = trainer.train_acc_list, trainer.test_acc_list

# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(len(train_acc_list))
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# train loss:2.3138899409178393
# === epoch:1, train acc:0.08333333333333333, test acc:0.0769 ===
# train loss:2.3045203647041093
# train loss:2.3031457028374733
# train loss:2.304263145215903
# === epoch:2, train acc:0.08666666666666667, test acc:0.0817 ===
# train loss:2.302534791410474
# train loss:2.3025728135934
# train loss:2.314940013307968
# === epoch:3, train acc:0.09333333333333334, test acc:0.0804 ===
# train loss:2.310692354018409
# train loss:2.2917156577535103
# train loss:2.2927288815071267
# === epoch:4, train acc:0.09, test acc:0.0849 ===
# train loss:2.3064979889897512
# train loss:2.3032263345452337
# train loss:2.310835825050368
# === epoch:5, train acc:0.09666666666666666, test acc:0.0884 ===
# train loss:2.3129936780713565
# train loss:2.298264264817493
# train loss:2.303961700069466
# === epoch:6, train acc:0.11666666666666667, test acc:0.0979 ===
# train loss:2.2996529082836292
# train loss:2.2944974564830947
# train loss:2.3004349021557484
# === epoch:7, train acc:0.12333333333333334, test acc:0.1016 ===
# train loss:2.30534902352576
# train loss:2.3037361437278023
# train loss:2.2976951763214175
# === epoch:8, train acc:0.11666666666666667, test acc:0.1083 ===
# train loss:2.2998738525759164
# train loss:2.293514998970911
# train loss:2.29215402406733
# === epoch:9, train acc:0.12333333333333334, test acc:0.115 ===
# train loss:2.2908257549044317
# train loss:2.3006511567304666
# train loss:2.285873272974956
# === epoch:10, train acc:0.13, test acc:0.122 ===
# train loss:2.286868935823829
# train loss:2.2932296067023867
# train loss:2.2918811109009956
# === epoch:11, train acc:0.13333333333333333, test acc:0.1265 ===
# train loss:2.29293838379156
# train loss:2.2892338911381573
# train loss:2.2781416222911917
# === epoch:12, train acc:0.15, test acc:0.1321 ===
# train loss:2.3041950420480455
# train loss:2.2941376008546484
# train loss:2.2882874178228767
# === epoch:13, train acc:0.14666666666666667, test acc:0.1354 ===
# train loss:2.2763770403389585
# train loss:2.2954969871408144
# train loss:2.2840529473091853
# === epoch:14, train acc:0.15, test acc:0.1365 ===
# train loss:2.2785883301749874
# train loss:2.277016909084428
# train loss:2.2861050551383695
# === epoch:15, train acc:0.15333333333333332, test acc:0.1405 ===
# train loss:2.2777693625572284
# train loss:2.2914722363851596
# train loss:2.286213065150832
# === epoch:16, train acc:0.17333333333333334, test acc:0.1428 ===
# train loss:2.2908106403491444
# train loss:2.282192853857397
# train loss:2.2999100913410033
# === epoch:17, train acc:0.17666666666666667, test acc:0.1432 ===
# train loss:2.2805974487798006
# train loss:2.2768619833106265
# train loss:2.282188606646704
# === epoch:18, train acc:0.17333333333333334, test acc:0.1435 ===
# train loss:2.290717086094146
# train loss:2.273495860878278
# train loss:2.2759581096470667
# === epoch:19, train acc:0.17666666666666667, test acc:0.1481 ===
# train loss:2.28893676347986
# train loss:2.2775342709214126
# train loss:2.271423910310644
# === epoch:20, train acc:0.18666666666666668, test acc:0.1503 ===
# train loss:2.2888333940161583
# train loss:2.281250257285504
# train loss:2.2717909697519123
# === epoch:21, train acc:0.19333333333333333, test acc:0.1508 ===
# train loss:2.288598423110268
# train loss:2.282349510683973
# train loss:2.2796237292757455
# === epoch:22, train acc:0.19, test acc:0.1556 ===
# train loss:2.2840089757328115
# train loss:2.2758361269209315
# train loss:2.269430864336478
# === epoch:23, train acc:0.19666666666666666, test acc:0.1576 ===
# train loss:2.2680784984549804
# train loss:2.2749925405803415
# train loss:2.271232340107105
# === epoch:24, train acc:0.20333333333333334, test acc:0.1596 ===
# train loss:2.265042345637516
# train loss:2.2726881661253553
# train loss:2.269752977341641
# === epoch:25, train acc:0.20333333333333334, test acc:0.1659 ===
# train loss:2.276402191220718
# train loss:2.2645442261165187
# train loss:2.271302915619967
# === epoch:26, train acc:0.21666666666666667, test acc:0.1687 ===
# train loss:2.260833770679093
# train loss:2.2628326596889448
# train loss:2.2770880034130423
# === epoch:27, train acc:0.22, test acc:0.1713 ===
# train loss:2.2580980575942506
# train loss:2.266894529835829
# train loss:2.2603968580309597
# === epoch:28, train acc:0.22333333333333333, test acc:0.1779 ===
# train loss:2.2742015474483663
# train loss:2.275825765398543
# train loss:2.2786615564763877
# === epoch:29, train acc:0.23333333333333334, test acc:0.1795 ===
# train loss:2.252327576386962
# train loss:2.2828970281495318
# train loss:2.266126459032859
# === epoch:30, train acc:0.23666666666666666, test acc:0.182 ===
# train loss:2.2623196629077507
# train loss:2.271402451981065
# train loss:2.27289237140381
# === epoch:31, train acc:0.24666666666666667, test acc:0.1839 ===
# train loss:2.259728743572779
# train loss:2.24998707148654
# train loss:2.251515959195802
# === epoch:32, train acc:0.24333333333333335, test acc:0.1838 ===
# train loss:2.259771594994049
# train loss:2.262430630019061
# train loss:2.2581010057457274
# === epoch:33, train acc:0.24666666666666667, test acc:0.1876 ===
# train loss:2.259439202566547
# train loss:2.267218178910123
# train loss:2.260230905921407
# === epoch:34, train acc:0.25666666666666665, test acc:0.1918 ===
# train loss:2.2601194417704824
# train loss:2.258055932529591
# train loss:2.256549376716836
# === epoch:35, train acc:0.25333333333333335, test acc:0.1929 ===
# train loss:2.271229857954621
# train loss:2.2676327039634314
# train loss:2.238957563489631
# === epoch:36, train acc:0.2633333333333333, test acc:0.1934 ===
# train loss:2.2535742776628136
# train loss:2.2551228645493975
# train loss:2.2634122955342018
# === epoch:37, train acc:0.26666666666666666, test acc:0.1971 ===
# train loss:2.2583865761678186
# train loss:2.2551421134013663
# train loss:2.275450018816213
# === epoch:38, train acc:0.26666666666666666, test acc:0.2002 ===
# train loss:2.2508023832033963
# train loss:2.263199553584817
# train loss:2.261189379872423
# === epoch:39, train acc:0.27, test acc:0.2011 ===
# train loss:2.2620561156790955
# train loss:2.2562509866923866
# train loss:2.2721446067516546
# === epoch:40, train acc:0.28, test acc:0.2054 ===
# train loss:2.2468433822236773
# train loss:2.2738736930957013
# train loss:2.2710689487517315
# === epoch:41, train acc:0.27, test acc:0.2077 ===
# train loss:2.247048415337602
# train loss:2.2539446544937047
# train loss:2.246452711568094
# === epoch:42, train acc:0.2733333333333333, test acc:0.2084 ===
# train loss:2.256413101829322
# train loss:2.2686682010849175
# train loss:2.239650804037694
# === epoch:43, train acc:0.28, test acc:0.21 ===
# train loss:2.2439859086579945
# train loss:2.2531169452785296
# train loss:2.268691216496424
# === epoch:44, train acc:0.28, test acc:0.2121 ===
# train loss:2.249468538367375
# train loss:2.260545753531039
# train loss:2.2559666938433818
# === epoch:45, train acc:0.27666666666666667, test acc:0.2106 ===
# train loss:2.266812755787163
# train loss:2.253579828369925
# train loss:2.2381424494587314
# === epoch:46, train acc:0.27666666666666667, test acc:0.2127 ===
# train loss:2.2384738682545606
# train loss:2.2474480811159325
# train loss:2.2594947724547114
# === epoch:47, train acc:0.27666666666666667, test acc:0.2129 ===
# train loss:2.250141464316277
# train loss:2.254130921088203
# train loss:2.2203443877470814
# === epoch:48, train acc:0.27666666666666667, test acc:0.2133 ===
# train loss:2.2616001598697277
# train loss:2.2562670524598993
# train loss:2.2271866959346087
# === epoch:49, train acc:0.29333333333333333, test acc:0.2163 ===
# train loss:2.2397103632835305
# train loss:2.2498334132672433
# train loss:2.24063321145635
# === epoch:50, train acc:0.2966666666666667, test acc:0.2176 ===
# train loss:2.2546489835747514
# train loss:2.2569732439538686
# train loss:2.251722619222335
# === epoch:51, train acc:0.29333333333333333, test acc:0.2188 ===
# train loss:2.2246033728169476
# train loss:2.2329957085583154
# train loss:2.2518799119392487
# === epoch:52, train acc:0.3, test acc:0.2169 ===
# train loss:2.244782969447917
# train loss:2.2528261981501982
# train loss:2.2442290677735723
# === epoch:53, train acc:0.30333333333333334, test acc:0.2184 ===
# train loss:2.239620252582833
# train loss:2.2384850075465526
# train loss:2.2126580870468304
# === epoch:54, train acc:0.29333333333333333, test acc:0.2199 ===
# train loss:2.2574782346214515
# train loss:2.249066571280603
# train loss:2.242538268740976
# === epoch:55, train acc:0.3, test acc:0.2238 ===
# train loss:2.245958154329385
# train loss:2.2390284462546974
# train loss:2.2446393071329367
# === epoch:56, train acc:0.30666666666666664, test acc:0.2248 ===
# train loss:2.235441268652121
# train loss:2.214736466935347
# train loss:2.25844449262973
# === epoch:57, train acc:0.31, test acc:0.2277 ===
# train loss:2.2373905368058207
# train loss:2.2421578058760163
# train loss:2.230864685818198
# === epoch:58, train acc:0.31, test acc:0.2276 ===
# train loss:2.2612692631843068
# train loss:2.2578768572272487
# train loss:2.2359876953870663
# === epoch:59, train acc:0.30666666666666664, test acc:0.2311 ===
# train loss:2.229635657067164
# train loss:2.203370461680679
# train loss:2.2333985841744126
# === epoch:60, train acc:0.30666666666666664, test acc:0.234 ===
# train loss:2.2184014352827073
# train loss:2.2261610620338597
# train loss:2.231371606938377
# === epoch:61, train acc:0.30666666666666664, test acc:0.2356 ===
# train loss:2.2205028670274594
# train loss:2.236067017400228
# train loss:2.2029784232683816
# === epoch:62, train acc:0.32, test acc:0.2395 ===
# train loss:2.2293514620136152
# train loss:2.202519027064919
# train loss:2.2393965033716907
# === epoch:63, train acc:0.31333333333333335, test acc:0.2383 ===
# train loss:2.2313074560713355
# train loss:2.2437541030949135
# train loss:2.2383855382763103
# === epoch:64, train acc:0.31, test acc:0.2367 ===
# train loss:2.2357778412997824
# train loss:2.2153772590764804
# train loss:2.1947488351970756
# === epoch:65, train acc:0.31, test acc:0.238 ===
# train loss:2.2127849533687733
# train loss:2.224707765342402
# train loss:2.225143096599817
# === epoch:66, train acc:0.31333333333333335, test acc:0.2375 ===
# train loss:2.2236858094278444
# train loss:2.195268999008288
# train loss:2.2077992399604667
# === epoch:67, train acc:0.30666666666666664, test acc:0.2382 ===
# train loss:2.200265952147933
# train loss:2.210657546357708
# train loss:2.2245811639200332
# === epoch:68, train acc:0.30666666666666664, test acc:0.2387 ===
# train loss:2.2051309311041374
# train loss:2.2397003977053545
# train loss:2.2283090892497435
# === epoch:69, train acc:0.31333333333333335, test acc:0.2384 ===
# train loss:2.2117751863288646
# train loss:2.2359263279508794
# train loss:2.2070555480432352
# === epoch:70, train acc:0.31333333333333335, test acc:0.2409 ===
# train loss:2.2243275289999804
# train loss:2.226751807932919
# train loss:2.216345018428488
# === epoch:71, train acc:0.32, test acc:0.2435 ===
# train loss:2.202975090014145
# train loss:2.2235197120320502
# train loss:2.2200995030522725
# === epoch:72, train acc:0.32666666666666666, test acc:0.2473 ===
# train loss:2.214919931755052
# train loss:2.212040879137405
# train loss:2.1914726460210865
# === epoch:73, train acc:0.32666666666666666, test acc:0.248 ===
# train loss:2.19089033208757
# train loss:2.223243118144027
# train loss:2.191588719641121
# === epoch:74, train acc:0.33, test acc:0.2477 ===
# train loss:2.2187957059843715
# train loss:2.198063806086557
# train loss:2.22651522654577
# === epoch:75, train acc:0.32666666666666666, test acc:0.25 ===
# train loss:2.180331389055514
# train loss:2.208850829995666
# train loss:2.212710567582629
# === epoch:76, train acc:0.3233333333333333, test acc:0.2498 ===
# train loss:2.1961186049606147
# train loss:2.213229435657725
# train loss:2.200543697561682
# === epoch:77, train acc:0.32666666666666666, test acc:0.2514 ===
# train loss:2.202350386472858
# train loss:2.209294820932953
# train loss:2.1903602779854565
# === epoch:78, train acc:0.32666666666666666, test acc:0.2541 ===
# train loss:2.1971834089846243
# train loss:2.189676237608215
# train loss:2.2132158753840483
# === epoch:79, train acc:0.33, test acc:0.2572 ===
# train loss:2.178186369084049
# train loss:2.2107041490286448
# train loss:2.2237423223454886
# === epoch:80, train acc:0.33, test acc:0.2594 ===
# train loss:2.18015930367241
# train loss:2.2186404339131376
# train loss:2.1771980575727135
# === epoch:81, train acc:0.33, test acc:0.2589 ===
# train loss:2.193459796132612
# train loss:2.172132248716157
# train loss:2.179089100894619
# === epoch:82, train acc:0.33, test acc:0.2594 ===
# train loss:2.1769271672887585
# train loss:2.1810425098547506
# train loss:2.185948259979888
# === epoch:83, train acc:0.32, test acc:0.2594 ===
# train loss:2.224640777165788
# train loss:2.182433805136631
# train loss:2.2133603738094716
# === epoch:84, train acc:0.32666666666666666, test acc:0.2602 ===
# train loss:2.2095620636831175
# train loss:2.178054456073168
# train loss:2.1833101983713523
# === epoch:85, train acc:0.3333333333333333, test acc:0.262 ===
# train loss:2.190934243884031
# train loss:2.1894319862225835
# train loss:2.1739635224749487
# === epoch:86, train acc:0.33666666666666667, test acc:0.2639 ===
# train loss:2.177434042708
# train loss:2.177983977451457
# train loss:2.1809896285868073
# === epoch:87, train acc:0.33, test acc:0.2645 ===
# train loss:2.1612277199716443
# train loss:2.19117825478716
# train loss:2.1604363715819996
# === epoch:88, train acc:0.3233333333333333, test acc:0.2622 ===
# train loss:2.191936623829277
# train loss:2.1836506909103215
# train loss:2.1656162594542376
# === epoch:89, train acc:0.34, test acc:0.2652 ===
# train loss:2.1647291938080038
# train loss:2.168256057360882
# train loss:2.1579007403753447
# === epoch:90, train acc:0.33666666666666667, test acc:0.2655 ===
# train loss:2.1944946870849393
# train loss:2.1763987731611154
# train loss:2.149227425654741
# === epoch:91, train acc:0.3333333333333333, test acc:0.266 ===
# train loss:2.176035281549518
# train loss:2.1567565762051824
# train loss:2.1789017494380625
# === epoch:92, train acc:0.3333333333333333, test acc:0.2661 ===
# train loss:2.1198010504505693
# train loss:2.157446406693475
# train loss:2.193919865697176
# === epoch:93, train acc:0.33666666666666667, test acc:0.2673 ===
# train loss:2.1493189905957273
# train loss:2.1658465527349695
# train loss:2.143988081403043
# === epoch:94, train acc:0.3333333333333333, test acc:0.2683 ===
# train loss:2.1847526160395203
# train loss:2.1605751651762533
# train loss:2.177539496760963
# === epoch:95, train acc:0.33666666666666667, test acc:0.2686 ===
# train loss:2.16431661129535
# train loss:2.1465534880077697
# train loss:2.162050019003832
# === epoch:96, train acc:0.33666666666666667, test acc:0.2696 ===
# train loss:2.149733156552862
# train loss:2.159744783508314
# train loss:2.1513030715933166
# === epoch:97, train acc:0.33666666666666667, test acc:0.2707 ===
# train loss:2.1694950350946636
# train loss:2.1319775538869066
# train loss:2.1701530771944846
# === epoch:98, train acc:0.33666666666666667, test acc:0.2705 ===
# train loss:2.139387879233505
# train loss:2.1450031625935466
# train loss:2.112209519511546
# === epoch:99, train acc:0.34, test acc:0.2707 ===
# train loss:2.170532000144253
# train loss:2.0995072378222557
# train loss:2.1248067492074734
# === epoch:100, train acc:0.34, test acc:0.2708 ===
# train loss:2.1490679533613273
# train loss:2.171451107546027
# train loss:2.1122242579774344
# === epoch:101, train acc:0.34, test acc:0.2716 ===
# train loss:2.112000247118923
# train loss:2.130313702410128
# train loss:2.1302389989476467
# === epoch:102, train acc:0.33666666666666667, test acc:0.2699 ===
# train loss:2.1462792778683526
# train loss:2.128094125626002
# train loss:2.0699760048062754
# === epoch:103, train acc:0.33666666666666667, test acc:0.2691 ===
# train loss:2.1373148462120097
# train loss:2.130270170052685
# train loss:2.135502241575787
# === epoch:104, train acc:0.33666666666666667, test acc:0.2707 ===
# train loss:2.1207940890533807
# train loss:2.094083181911965
# train loss:2.1388406443186327
# === epoch:105, train acc:0.33666666666666667, test acc:0.2695 ===
# train loss:2.094575003856947
# train loss:2.1682851471904123
# train loss:2.1019348835501295
# === epoch:106, train acc:0.3433333333333333, test acc:0.2715 ===
# train loss:2.122292857705869
# train loss:2.103724610863559
# train loss:2.1473754972938677
# === epoch:107, train acc:0.3466666666666667, test acc:0.2719 ===
# train loss:2.1011329900949134
# train loss:2.10213755523808
# train loss:2.146716230903014
# === epoch:108, train acc:0.33666666666666667, test acc:0.2695 ===
# train loss:2.1039750672335513
# train loss:2.0952385291136584
# train loss:2.124979214695784
# === epoch:109, train acc:0.34, test acc:0.2693 ===
# train loss:2.0875024349849003
# train loss:2.084979304727744
# train loss:2.133648098325916
# === epoch:110, train acc:0.3433333333333333, test acc:0.27 ===
# train loss:2.1091418064736533
# train loss:2.1007620942469303
# train loss:2.1124335914337493
# === epoch:111, train acc:0.3433333333333333, test acc:0.2716 ===
# train loss:2.1355325408099444
# train loss:2.0990734910467923
# train loss:2.1051954066869607
# === epoch:112, train acc:0.35, test acc:0.2705 ===
# train loss:2.045978116832694
# train loss:2.123651148681179
# train loss:2.1171070003326857
# === epoch:113, train acc:0.35, test acc:0.2707 ===
# train loss:2.069471906242682
# train loss:2.1034991887709413
# train loss:2.0854814394329906
# === epoch:114, train acc:0.35, test acc:0.2712 ===
# train loss:2.109963726811759
# train loss:2.1007913658226194
# train loss:2.080110821545672
# === epoch:115, train acc:0.35, test acc:0.2714 ===
# train loss:2.0584170405580533
# train loss:2.0995072754409834
# train loss:2.116966723601369
# === epoch:116, train acc:0.35, test acc:0.2724 ===
# train loss:2.141936744710789
# train loss:2.0998012124731007
# train loss:2.11351520807115
# === epoch:117, train acc:0.35333333333333333, test acc:0.2741 ===
# train loss:2.0932789086972234
# train loss:2.0372596859867618
# train loss:2.027640580891449
# === epoch:118, train acc:0.35, test acc:0.2713 ===
# train loss:2.063820166856403
# train loss:2.079605726430592
# train loss:2.08244713211978
# === epoch:119, train acc:0.35333333333333333, test acc:0.2711 ===
# train loss:2.036848862179332
# train loss:2.045669071434194
# train loss:1.976194637117423
# === epoch:120, train acc:0.3466666666666667, test acc:0.2697 ===
# train loss:2.0947350587698836
# train loss:2.023049269762119
# train loss:2.0964803725549865
# === epoch:121, train acc:0.35333333333333333, test acc:0.2709 ===
# train loss:2.045991414191136
# train loss:1.9838223226045058
# train loss:2.1260857849427
# === epoch:122, train acc:0.36333333333333334, test acc:0.275 ===
# train loss:2.0638649437640044
# train loss:2.063309770370216
# train loss:2.053344451147087
# === epoch:123, train acc:0.36333333333333334, test acc:0.2743 ===
# train loss:2.0652331048383634
# train loss:2.1187686802893335
# train loss:1.9978313133739494
# === epoch:124, train acc:0.36333333333333334, test acc:0.2778 ===
# train loss:2.0933863339733234
# train loss:2.0674640013802694
# train loss:2.0454074207812405
# === epoch:125, train acc:0.36666666666666664, test acc:0.2812 ===
# train loss:2.0040432085650757
# train loss:2.024254227963867
# train loss:2.086192062597348
# === epoch:126, train acc:0.36666666666666664, test acc:0.2829 ===
# train loss:2.1332738960359645
# train loss:2.0841036231815204
# train loss:2.0201138539315187
# === epoch:127, train acc:0.37, test acc:0.287 ===
# train loss:2.004947859132253
# train loss:1.985298585742962
# train loss:1.9934540090927597
# === epoch:128, train acc:0.37, test acc:0.2861 ===
# train loss:1.9975549519817366
# train loss:2.0173503695522337
# train loss:2.053682024101127
# === epoch:129, train acc:0.37333333333333335, test acc:0.2879 ===
# train loss:2.082439616917825
# train loss:2.0335045204474484
# train loss:2.05216228391865
# === epoch:130, train acc:0.37, test acc:0.2909 ===
# train loss:2.0383427431918797
# train loss:2.032635213222177
# train loss:2.069974919919734
# === epoch:131, train acc:0.37, test acc:0.2922 ===
# train loss:2.0465830322348744
# train loss:2.0461712331957873
# train loss:2.09867573117254
# === epoch:132, train acc:0.37, test acc:0.2944 ===
# train loss:2.0586999949479274
# train loss:1.9532201712348063
# train loss:1.985539108378604
# === epoch:133, train acc:0.37666666666666665, test acc:0.2954 ===
# train loss:2.0177097638643473
# train loss:2.025259385908771
# train loss:2.057276980874943
# === epoch:134, train acc:0.38, test acc:0.3009 ===
# train loss:2.0088906403741413
# train loss:1.9700456776556448
# train loss:1.9874692994542478
# === epoch:135, train acc:0.38333333333333336, test acc:0.3019 ===
# train loss:2.0539687698392144
# train loss:2.0371914745298594
# train loss:1.9924789712625954
# === epoch:136, train acc:0.38666666666666666, test acc:0.3008 ===
# train loss:1.9608433603246127
# train loss:2.0078087715694015
# train loss:2.0501570943433953
# === epoch:137, train acc:0.38666666666666666, test acc:0.3036 ===
# train loss:2.0635920529868472
# train loss:2.0246156315566246
# train loss:2.087760512941238
# === epoch:138, train acc:0.3933333333333333, test acc:0.3081 ===
# train loss:1.9906292800164926
# train loss:2.00505424552888
# train loss:2.0218242808950184
# === epoch:139, train acc:0.39666666666666667, test acc:0.3078 ===
# train loss:1.9990042134060986
# train loss:1.9846016924281031
# train loss:2.017077493979076
# === epoch:140, train acc:0.39, test acc:0.3063 ===
# train loss:2.045116048134702
# train loss:2.0228030430391417
# train loss:1.9527276021397912
# === epoch:141, train acc:0.4, test acc:0.3177 ===
# train loss:2.0303883569996284
# train loss:1.9644865026762581
# train loss:1.9335074901630704
# === epoch:142, train acc:0.4, test acc:0.319 ===
# train loss:1.9560355294737075
# train loss:1.9852862905260216
# train loss:1.9400791884087374
# === epoch:143, train acc:0.4, test acc:0.3203 ===
# train loss:1.9194907012729499
# train loss:1.9374178299229499
# train loss:1.8999552200967293
# === epoch:144, train acc:0.4033333333333333, test acc:0.3234 ===
# train loss:2.0034765188720973
# train loss:2.0085651859665483
# train loss:1.9712757885982253
# === epoch:145, train acc:0.41, test acc:0.3285 ===
# train loss:1.937907324810285
# train loss:1.9484185107760998
# train loss:2.070327309215865
# === epoch:146, train acc:0.41333333333333333, test acc:0.3332 ===
# train loss:1.9072239631402423
# train loss:1.9757581103831519
# train loss:1.940788193686102
# === epoch:147, train acc:0.41333333333333333, test acc:0.3367 ===
# train loss:1.9170716932653322
# train loss:2.0432677871883187
# train loss:1.9419776634281904
# === epoch:148, train acc:0.4166666666666667, test acc:0.3376 ===
# train loss:1.9883712000322566
# train loss:1.9986528147291924
# train loss:1.9143424243960638
# === epoch:149, train acc:0.42, test acc:0.3419 ===
# train loss:1.9469916777854401
# train loss:1.9332375791628018
# train loss:1.9499779245262479
# === epoch:150, train acc:0.42, test acc:0.3469 ===
# train loss:1.938684292591063
# train loss:1.9022302836294043
# train loss:1.8741600164923178
# === epoch:151, train acc:0.4166666666666667, test acc:0.3396 ===
# train loss:1.8402777634128993
# train loss:1.867553150825734
# train loss:1.9853001772273011
# === epoch:152, train acc:0.41333333333333333, test acc:0.3381 ===
# train loss:1.9165471984897804
# train loss:1.9330713800858
# train loss:1.9284756259113456
# === epoch:153, train acc:0.42, test acc:0.3433 ===
# train loss:1.8971173667470007
# train loss:1.8925030260741074
# train loss:1.9183514814032165
# === epoch:154, train acc:0.41333333333333333, test acc:0.3436 ===
# train loss:1.899588607665057
# train loss:1.8898903061968837
# train loss:1.9313114628612629
# === epoch:155, train acc:0.42333333333333334, test acc:0.3534 ===
# train loss:1.8801640515886595
# train loss:1.9278552649989968
# train loss:1.7842984681953862
# === epoch:156, train acc:0.42, test acc:0.3512 ===
# train loss:1.9404402484995231
# train loss:1.8792674407287375
# train loss:1.862843761340939
# === epoch:157, train acc:0.42333333333333334, test acc:0.3518 ===
# train loss:1.8433588974638768
# train loss:1.8801485593275942
# train loss:1.8820731109684832
# === epoch:158, train acc:0.42333333333333334, test acc:0.3551 ===
# train loss:1.9981091574264815
# train loss:1.8234999916306498
# train loss:1.8123373238928888
# === epoch:159, train acc:0.4166666666666667, test acc:0.3552 ===
# train loss:1.7466025593837748
# train loss:1.7860049558789262
# train loss:1.9398548020349065
# === epoch:160, train acc:0.42, test acc:0.3538 ===
# train loss:1.815090180826198
# train loss:1.871686413332381
# train loss:1.8490109816868796
# === epoch:161, train acc:0.42333333333333334, test acc:0.3545 ===
# train loss:1.8360663845022192
# train loss:1.8682176390444731
# train loss:1.9293604000339946
# === epoch:162, train acc:0.42, test acc:0.3555 ===
# train loss:1.9305655915726578
# train loss:1.9046379434719822
# train loss:1.8033551408606217
# === epoch:163, train acc:0.42, test acc:0.3567 ===
# train loss:1.847792862924454
# train loss:1.849054322734344
# train loss:1.8779962867471016
# === epoch:164, train acc:0.4266666666666667, test acc:0.3582 ===
# train loss:1.8332121498635723
# train loss:1.8666918970380153
# train loss:1.7860611473499557
# === epoch:165, train acc:0.42, test acc:0.3608 ===
# train loss:1.9077396034729248
# train loss:1.8407313854687863
# train loss:1.8744898382655102
# === epoch:166, train acc:0.42, test acc:0.3601 ===
# train loss:1.70641211819803
# train loss:1.8877023638356925
# train loss:1.7791797456192922
# === epoch:167, train acc:0.43, test acc:0.3632 ===
# train loss:1.7566327907041386
# train loss:1.6944547024557193
# train loss:1.825025538624888
# === epoch:168, train acc:0.4266666666666667, test acc:0.3622 ===
# train loss:1.819655103817527
# train loss:1.8011162024121676
# train loss:1.8813318154509917
# === epoch:169, train acc:0.43, test acc:0.3662 ===
# train loss:1.9361172711807626
# train loss:1.7738008985917155
# train loss:1.9137256384445567
# === epoch:170, train acc:0.43666666666666665, test acc:0.3718 ===
# train loss:1.800019387425019
# train loss:1.7810081725087354
# train loss:1.8833463403886386
# === epoch:171, train acc:0.43666666666666665, test acc:0.3745 ===
# train loss:1.7852181338546174
# train loss:1.8378140887288938
# train loss:1.7889976882829546
# === epoch:172, train acc:0.45, test acc:0.3776 ===
# train loss:1.9596732830323607
# train loss:1.88447400812693
# train loss:1.7560283348963404
# === epoch:173, train acc:0.45666666666666667, test acc:0.3811 ===
# train loss:1.7929919357194117
# train loss:1.7822817199197134
# train loss:1.7128542328931908
# === epoch:174, train acc:0.45666666666666667, test acc:0.381 ===
# train loss:1.7439186760328729
# train loss:1.8683152587188983
# train loss:1.841094881353446
# === epoch:175, train acc:0.46, test acc:0.3847 ===
# train loss:1.7433183253499607
# train loss:1.8507576206388572
# train loss:1.7527717951958197
# === epoch:176, train acc:0.4633333333333333, test acc:0.3853 ===
# train loss:1.8638203019680872
# train loss:1.770284615201777
# train loss:1.8058180148027387
# === epoch:177, train acc:0.47, test acc:0.3863 ===
# train loss:1.828727093245954
# train loss:1.79536481634708
# train loss:1.6533951578298325
# === epoch:178, train acc:0.47333333333333333, test acc:0.3883 ===
# train loss:1.7916987602461587
# train loss:1.8366191696783776
# train loss:1.8422015651893175
# === epoch:179, train acc:0.47333333333333333, test acc:0.3935 ===
# train loss:1.7393684586008193
# train loss:1.7793510502067207
# train loss:1.6491787440019052
# === epoch:180, train acc:0.48, test acc:0.3946 ===
# train loss:1.8315807655314402
# train loss:1.7102856725010134
# train loss:1.8423559053286847
# === epoch:181, train acc:0.48333333333333334, test acc:0.3973 ===
# train loss:1.8328125542902598
# train loss:1.7885956688050713
# train loss:1.8092036722001104
# === epoch:182, train acc:0.47333333333333333, test acc:0.3979 ===
# train loss:1.6321309553108139
# train loss:1.6366817616974447
# train loss:1.6858821285625938
# === epoch:183, train acc:0.47333333333333333, test acc:0.3943 ===
# train loss:1.8668810158569173
# train loss:1.7539587165175985
# train loss:1.7089371546364671
# === epoch:184, train acc:0.47333333333333333, test acc:0.3969 ===
# train loss:1.7002444459783401
# train loss:1.808828330814737
# train loss:1.7535960101009496
# === epoch:185, train acc:0.4666666666666667, test acc:0.4006 ===
# train loss:1.73478307006319
# train loss:1.7924846428844772
# train loss:1.657730294335372
# === epoch:186, train acc:0.47, test acc:0.403 ===
# train loss:1.6927554684019903
# train loss:1.6572474497245449
# train loss:1.684895125722893
# === epoch:187, train acc:0.47333333333333333, test acc:0.4034 ===
# train loss:1.55422865347977
# train loss:1.7028074202359142
# train loss:1.7350512079952947
# === epoch:188, train acc:0.46, test acc:0.3977 ===
# train loss:1.7853011509720138
# train loss:1.678621510126013
# train loss:1.7957917603884115
# === epoch:189, train acc:0.4666666666666667, test acc:0.3988 ===
# train loss:1.791382918329793
# train loss:1.666981301022898
# train loss:1.7953379320041334
# === epoch:190, train acc:0.47333333333333333, test acc:0.3999 ===
# train loss:1.663251427501406
# train loss:1.6753157332392337
# train loss:1.8522269954075155
# === epoch:191, train acc:0.47333333333333333, test acc:0.3978 ===
# train loss:1.556595505662691
# train loss:1.6984169037316814
# train loss:1.7133281510720388
# === epoch:192, train acc:0.4766666666666667, test acc:0.3988 ===
# train loss:1.6509658763923554
# train loss:1.796946315686413
# train loss:1.6066010906452917
# === epoch:193, train acc:0.4766666666666667, test acc:0.3982 ===
# train loss:1.6378873645140573
# train loss:1.6955279888951063
# train loss:1.7542938936891022
# === epoch:194, train acc:0.48333333333333334, test acc:0.4014 ===
# train loss:1.7252899191115316
# train loss:1.7023925852858302
# train loss:1.7526555937704134
# === epoch:195, train acc:0.49333333333333335, test acc:0.4042 ===
# train loss:1.7844251923757062
# train loss:1.5524320240837612
# train loss:1.4743573597089585
# === epoch:196, train acc:0.49, test acc:0.403 ===
# train loss:1.6932758291865628
# train loss:1.663125289956948
# train loss:1.709256731516447
# === epoch:197, train acc:0.48333333333333334, test acc:0.4024 ===
# train loss:1.518498300678358
# train loss:1.602402222057174
# train loss:1.5681663034729214
# === epoch:198, train acc:0.48333333333333334, test acc:0.4008 ===
# train loss:1.7646909655141534
# train loss:1.7949863271838746
# train loss:1.688580482286303
# === epoch:199, train acc:0.48333333333333334, test acc:0.4053 ===
# train loss:1.6964059149281272
# train loss:1.761862546205287
# train loss:1.687147703405062
# === epoch:200, train acc:0.47333333333333333, test acc:0.404 ===
# train loss:1.695023431031751
# train loss:1.6008009792152547
# train loss:1.5315790459789616
# === epoch:201, train acc:0.47333333333333333, test acc:0.4056 ===
# train loss:1.5855096631340215
# train loss:1.5217729376717868
# train loss:1.7352242510953704
# === epoch:202, train acc:0.47333333333333333, test acc:0.4061 ===
# train loss:1.6385357826506226
# train loss:1.5415165514696756
# train loss:1.61583666137305
# === epoch:203, train acc:0.48333333333333334, test acc:0.4054 ===
# train loss:1.6544127949791885
# train loss:1.6579260152237696
# train loss:1.5396348936271553
# === epoch:204, train acc:0.48333333333333334, test acc:0.4058 ===
# train loss:1.6716361790815946
# train loss:1.6160572905900166
# train loss:1.651667636505217
# === epoch:205, train acc:0.48333333333333334, test acc:0.4076 ===
# train loss:1.5480389584328274
# train loss:1.4684678911640041
# train loss:1.6049301626398895
# === epoch:206, train acc:0.48333333333333334, test acc:0.4037 ===
# train loss:1.5901348743129577
# train loss:1.558190510790386
# train loss:1.5588426212816173
# === epoch:207, train acc:0.48333333333333334, test acc:0.406 ===
# train loss:1.6575381921867216
# train loss:1.5719962710103221
# train loss:1.7071191106693135
# === epoch:208, train acc:0.48333333333333334, test acc:0.4058 ===
# train loss:1.597974058392004
# train loss:1.6060208467248518
# train loss:1.5957080949952702
# === epoch:209, train acc:0.47333333333333333, test acc:0.4062 ===
# train loss:1.6465887046118421
# train loss:1.4852074813943268
# train loss:1.7678847724898852
# === epoch:210, train acc:0.4766666666666667, test acc:0.4061 ===
# train loss:1.4640341830087358
# train loss:1.614133812693071
# train loss:1.5886803062642907
# === epoch:211, train acc:0.48333333333333334, test acc:0.408 ===
# train loss:1.5535065177080356
# train loss:1.6480965909943441
# train loss:1.6631467964503388
# === epoch:212, train acc:0.48, test acc:0.4084 ===
# train loss:1.6791620023270872
# train loss:1.535820098616069
# train loss:1.5879650506271918
# === epoch:213, train acc:0.49, test acc:0.411 ===
# train loss:1.6383317871532201
# train loss:1.5741528441923451
# train loss:1.5429479122341412
# === epoch:214, train acc:0.49666666666666665, test acc:0.4117 ===
# train loss:1.5421531159451891
# train loss:1.450094823660923
# train loss:1.54481266094622
# === epoch:215, train acc:0.5033333333333333, test acc:0.4118 ===
# train loss:1.5011355320308264
# train loss:1.578016522234928
# train loss:1.4814557342692474
# === epoch:216, train acc:0.49666666666666665, test acc:0.4141 ===
# train loss:1.5945212895943583
# train loss:1.6018179354058804
# train loss:1.656115842793712
# === epoch:217, train acc:0.49666666666666665, test acc:0.4164 ===
# train loss:1.6832484738224966
# train loss:1.6606156368578489
# train loss:1.4962849009349213
# === epoch:218, train acc:0.48333333333333334, test acc:0.4157 ===
# train loss:1.6474764378671287
# train loss:1.5854102328320225
# train loss:1.6282397711621985
# === epoch:219, train acc:0.49333333333333335, test acc:0.4173 ===
# train loss:1.4997324315297826
# train loss:1.3962529827548236
# train loss:1.6539499812482206
# === epoch:220, train acc:0.49333333333333335, test acc:0.4169 ===
# train loss:1.5026464743995367
# train loss:1.6064773683911608
# train loss:1.5153895609630788
# === epoch:221, train acc:0.49666666666666665, test acc:0.418 ===
# train loss:1.5239747067957583
# train loss:1.4796393036078512
# train loss:1.4752930746201778
# === epoch:222, train acc:0.5033333333333333, test acc:0.4172 ===
# train loss:1.4683375155897276
# train loss:1.4457577074230834
# train loss:1.57726224709857
# === epoch:223, train acc:0.5033333333333333, test acc:0.4183 ===
# train loss:1.5393391074281155
# train loss:1.489887951223263
# train loss:1.4927955418455254
# === epoch:224, train acc:0.5066666666666667, test acc:0.4188 ===
# train loss:1.6343819859581934
# train loss:1.6167619513762361
# train loss:1.5532582669316792
# === epoch:225, train acc:0.51, test acc:0.4183 ===
# train loss:1.4829283227236945
# train loss:1.5980585572058814
# train loss:1.4615999334144476
# === epoch:226, train acc:0.5033333333333333, test acc:0.4216 ===
# train loss:1.5196045059243508
# train loss:1.562305252508281
# train loss:1.6330274342988633
# === epoch:227, train acc:0.51, test acc:0.4229 ===
# train loss:1.4870594764462377
# train loss:1.5360260549425275
# train loss:1.4588477646741485
# === epoch:228, train acc:0.5066666666666667, test acc:0.4225 ===
# train loss:1.476436171026463
# train loss:1.5832924329790634
# train loss:1.3688792763720539
# === epoch:229, train acc:0.5066666666666667, test acc:0.4217 ===
# train loss:1.4815926190253896
# train loss:1.4511553142639908
# train loss:1.396866732500841
# === epoch:230, train acc:0.5066666666666667, test acc:0.4231 ===
# train loss:1.3709139582728478
# train loss:1.5332329413098718
# train loss:1.4198564969693548
# === epoch:231, train acc:0.5133333333333333, test acc:0.4231 ===
# train loss:1.4192474625386224
# train loss:1.5117699679955285
# train loss:1.4490273203548336
# === epoch:232, train acc:0.5133333333333333, test acc:0.4225 ===
# train loss:1.2458047768735274
# train loss:1.4400456011473097
# train loss:1.4749772664689136
# === epoch:233, train acc:0.5066666666666667, test acc:0.4204 ===
# train loss:1.4716208485229492
# train loss:1.5322572783581783
# train loss:1.523404224998378
# === epoch:234, train acc:0.5033333333333333, test acc:0.4198 ===
# train loss:1.4479941727836334
# train loss:1.4640640299465033
# train loss:1.3894245384784463
# === epoch:235, train acc:0.5066666666666667, test acc:0.4213 ===
# train loss:1.496435295972112
# train loss:1.6070936094780612
# train loss:1.4578694557430487
# === epoch:236, train acc:0.5066666666666667, test acc:0.4227 ===
# train loss:1.3186882294286335
# train loss:1.4968646654959736
# train loss:1.4193295336028675
# === epoch:237, train acc:0.5166666666666667, test acc:0.4215 ===
# train loss:1.401859863204704
# train loss:1.3759684276252286
# train loss:1.2737492115422504
# === epoch:238, train acc:0.52, test acc:0.4237 ===
# train loss:1.506673255636308
# train loss:1.4764678119040096
# train loss:1.4135359285898768
# === epoch:239, train acc:0.5133333333333333, test acc:0.4251 ===
# train loss:1.3875446007332355
# train loss:1.3938838049375517
# train loss:1.2654220727219614
# === epoch:240, train acc:0.5133333333333333, test acc:0.4248 ===
# train loss:1.3942285211628214
# train loss:1.519055383822563
# train loss:1.4348098992597473
# === epoch:241, train acc:0.51, test acc:0.426 ===
# train loss:1.3262007622748206
# train loss:1.4701734452813204
# train loss:1.4546055904734012
# === epoch:242, train acc:0.5066666666666667, test acc:0.4276 ===
# train loss:1.4149008433950443
# train loss:1.3170770927393798
# train loss:1.2927110651081994
# === epoch:243, train acc:0.5066666666666667, test acc:0.4259 ===
# train loss:1.3846421991344062
# train loss:1.3819514345280313
# train loss:1.4780012945606225
# === epoch:244, train acc:0.5033333333333333, test acc:0.4244 ===
# train loss:1.2236169416188545
# train loss:1.3507615590178406
# train loss:1.378723081361522
# === epoch:245, train acc:0.5033333333333333, test acc:0.4253 ===
# train loss:1.4047206367942409
# train loss:1.2926584783770536
# train loss:1.416093051169675
# === epoch:246, train acc:0.5033333333333333, test acc:0.4262 ===
# train loss:1.4572296132017286
# train loss:1.5697133744931326
# train loss:1.3295625802813884
# === epoch:247, train acc:0.5033333333333333, test acc:0.4273 ===
# train loss:1.3890518318492897
# train loss:1.3085335814662284
# train loss:1.3871272190327875
# === epoch:248, train acc:0.5066666666666667, test acc:0.4255 ===
# train loss:1.4726760788349365
# train loss:1.4690405082325224
# train loss:1.5334265739111066
# === epoch:249, train acc:0.51, test acc:0.4259 ===
# train loss:1.238564815098865
# train loss:1.3454048245420915
# train loss:1.3795151726429165
# === epoch:250, train acc:0.51, test acc:0.4299 ===
# train loss:1.3329190932549995
# train loss:1.3353862490339774
# train loss:1.3742909953514866
# === epoch:251, train acc:0.5133333333333333, test acc:0.4277 ===
# train loss:1.4025866811217795
# train loss:1.3546302102022607
# train loss:1.467628595861731
# === epoch:252, train acc:0.5133333333333333, test acc:0.4259 ===
# train loss:1.4198800845710067
# train loss:1.3211901924966951
# train loss:1.4298087439304
# === epoch:253, train acc:0.5166666666666667, test acc:0.4263 ===
# train loss:1.4039936182768813
# train loss:1.4585351507942497
# train loss:1.4262013602658383
# === epoch:254, train acc:0.52, test acc:0.4305 ===
# train loss:1.4286143407771328
# train loss:1.3753658645765585
# train loss:1.4499977795054906
# === epoch:255, train acc:0.5166666666666667, test acc:0.4281 ===
# train loss:1.2818421037594507
# train loss:1.4105608849591516
# train loss:1.4157513380102913
# === epoch:256, train acc:0.5166666666666667, test acc:0.4296 ===
# train loss:1.359151704751975
# train loss:1.3177373233488765
# train loss:1.237462127463337
# === epoch:257, train acc:0.52, test acc:0.4303 ===
# train loss:1.4124499484504067
# train loss:1.3542569787447252
# train loss:1.3679534667356712
# === epoch:258, train acc:0.5233333333333333, test acc:0.4316 ===
# train loss:1.3284596616776922
# train loss:1.2018589403932871
# train loss:1.401221654500487
# === epoch:259, train acc:0.52, test acc:0.4325 ===
# train loss:1.2202837938238087
# train loss:1.3252390417230884
# train loss:1.208090532049668
# === epoch:260, train acc:0.5266666666666666, test acc:0.4343 ===
# train loss:1.4033845420435818
# train loss:1.270324970370031
# train loss:1.319301887304461
# === epoch:261, train acc:0.53, test acc:0.4347 ===
# train loss:1.3911176207767835
# train loss:1.3361552644701993
# train loss:1.4007164986225478
# === epoch:262, train acc:0.5266666666666666, test acc:0.4317 ===
# train loss:1.2500220338201224
# train loss:1.2123113191417776
# train loss:1.301108105177789
# === epoch:263, train acc:0.53, test acc:0.432 ===
# train loss:1.3536607266308125
# train loss:1.4031006616771697
# train loss:1.3496202914027216
# === epoch:264, train acc:0.5266666666666666, test acc:0.4309 ===
# train loss:1.3505548549224906
# train loss:1.3396037719895102
# train loss:1.351283939089635
# === epoch:265, train acc:0.5166666666666667, test acc:0.4297 ===
# train loss:1.3326820124067493
# train loss:1.2959703815425427
# train loss:1.2675388910863894
# === epoch:266, train acc:0.5166666666666667, test acc:0.4303 ===
# train loss:1.3746128377228866
# train loss:1.2639570511155436
# train loss:1.3103992802819733
# === epoch:267, train acc:0.5266666666666666, test acc:0.4337 ===
# train loss:1.2893444819626023
# train loss:1.3049537590045346
# train loss:1.1815359097284506
# === epoch:268, train acc:0.5366666666666666, test acc:0.4336 ===
# train loss:1.3295985537745536
# train loss:1.2926707328985167
# train loss:1.248401534813309
# === epoch:269, train acc:0.54, test acc:0.4351 ===
# train loss:1.3001331541477075
# train loss:1.157747365171218
# train loss:1.312911352651548
# === epoch:270, train acc:0.5366666666666666, test acc:0.4348 ===
# train loss:1.282938315732364
# train loss:1.2012576976662486
# train loss:1.4149465272297388
# === epoch:271, train acc:0.5433333333333333, test acc:0.4357 ===
# train loss:1.3047826936689995
# train loss:1.323786018390025
# train loss:1.2863525007687076
# === epoch:272, train acc:0.54, test acc:0.4349 ===
# train loss:1.302901436176501
# train loss:1.186688608981636
# train loss:1.2917669163459298
# === epoch:273, train acc:0.5466666666666666, test acc:0.438 ===
# train loss:1.3837907860949037
# train loss:1.2521196396013428
# train loss:1.2210442426486363
# === epoch:274, train acc:0.5533333333333333, test acc:0.4362 ===
# train loss:1.1368395389142372
# train loss:1.2544870224021976
# train loss:1.282378836248192
# === epoch:275, train acc:0.55, test acc:0.4403 ===
# train loss:1.234549696388283
# train loss:1.1526397820928884
# train loss:1.1208627781943599
# === epoch:276, train acc:0.5533333333333333, test acc:0.4405 ===
# train loss:1.2680776765383883
# train loss:1.0899124421341364
# train loss:1.260878415781333
# === epoch:277, train acc:0.54, test acc:0.4431 ===
# train loss:1.293592183590035
# train loss:1.3043389650412076
# train loss:1.1810892183062984
# === epoch:278, train acc:0.54, test acc:0.4431 ===
# train loss:1.2512883428522499
# train loss:1.2600636642306613
# train loss:1.2387798201823423
# === epoch:279, train acc:0.5366666666666666, test acc:0.4437 ===
# train loss:1.1808718668530782
# train loss:1.130283269073749
# train loss:1.2221941558055789
# === epoch:280, train acc:0.5333333333333333, test acc:0.44 ===
# train loss:1.1480233974317664
# train loss:1.19870539504892
# train loss:1.1481008809658346
# === epoch:281, train acc:0.5333333333333333, test acc:0.4386 ===
# train loss:1.2706883730715237
# train loss:1.31736548239775
# train loss:1.1921184911833587
# === epoch:282, train acc:0.5333333333333333, test acc:0.439 ===
# train loss:1.1902668380500934
# train loss:1.0964220019048816
# train loss:1.2646225924534316
# === epoch:283, train acc:0.5433333333333333, test acc:0.4391 ===
# train loss:1.119611385602373
# train loss:1.1074545402604552
# train loss:1.2753464508243362
# === epoch:284, train acc:0.5333333333333333, test acc:0.4378 ===
# train loss:1.114396760395121
# train loss:1.1862941569767742
# train loss:1.2237920949248189
# === epoch:285, train acc:0.5166666666666667, test acc:0.4366 ===
# train loss:1.182206932276255
# train loss:1.2467572450468318
# train loss:1.340344797885357
# === epoch:286, train acc:0.5266666666666666, test acc:0.4366 ===
# train loss:1.1989490058795989
# train loss:1.134695231113778
# train loss:1.1735836963585298
# === epoch:287, train acc:0.5233333333333333, test acc:0.4409 ===
# train loss:1.1900761473558512
# train loss:1.2619843938880657
# train loss:1.2644876844884718
# === epoch:288, train acc:0.53, test acc:0.4427 ===
# train loss:1.1732965232867343
# train loss:1.2660809728764504
# train loss:1.20766663763506
# === epoch:289, train acc:0.5433333333333333, test acc:0.4442 ===
# train loss:1.2590729619168557
# train loss:1.210283710237037
# train loss:1.1699735439658876
# === epoch:290, train acc:0.5433333333333333, test acc:0.4465 ===
# train loss:1.1979611041785625
# train loss:1.1914015905197346
# train loss:1.2328412982895611
# === epoch:291, train acc:0.5433333333333333, test acc:0.4492 ===
# train loss:1.248480983835389
# train loss:1.0890923779242456
# train loss:1.075895288802164
# === epoch:292, train acc:0.5566666666666666, test acc:0.4598 ===
# train loss:1.0415723638494192
# train loss:1.1115593792071556
# train loss:1.356098297355742
# === epoch:293, train acc:0.55, test acc:0.4586 ===
# train loss:1.144229368981053
# train loss:1.2161044115713207
# train loss:1.1816671842337532
# === epoch:294, train acc:0.5533333333333333, test acc:0.4568 ===
# train loss:1.2576823940332753
# train loss:1.0749031314556812
# train loss:1.1252132970599076
# === epoch:295, train acc:0.56, test acc:0.4619 ===
# train loss:1.0070128353821293
# train loss:1.2983635208534983
# train loss:1.2776149045087988
# === epoch:296, train acc:0.56, test acc:0.4654 ===
# train loss:1.0777709441429086
# train loss:0.9376315133700346
# train loss:1.1714438439019232
# === epoch:297, train acc:0.5633333333333334, test acc:0.4654 ===
# train loss:1.2950597174389162
# train loss:1.0944858841130851
# train loss:1.157015914158993
# === epoch:298, train acc:0.5666666666666667, test acc:0.463 ===
# train loss:1.0238902970401815
# train loss:1.1992448344992164
# train loss:1.1231191474938864
# === epoch:299, train acc:0.57, test acc:0.4654 ===
# train loss:1.0663549474332497
# train loss:1.1335171818897973
# train loss:1.0868802321178515
# === epoch:300, train acc:0.5666666666666667, test acc:0.4616 ===
# train loss:1.0764153046038585
# train loss:1.0896864060542135
# train loss:1.0649597128998602
# === epoch:301, train acc:0.5633333333333334, test acc:0.462 ===
# train loss:0.9686471004519781
# train loss:1.1058464172222302
# =============== Final Test Accuracy ===============
# test acc:0.4584

# %%
# 하이퍼 파라미터 조정 예제
# validation data 설정

from common.util import *


(x_train, t_train), (x_test, t_test) = load_mnist()

# 훈련 데이터 셔플
x_train, t_train = shuffle_dataset(x_train, t_train)

# 20%를 검증 데이터로 val data
validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)

x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]

# %%
# 하이퍼 파라미터 무작위 추출
weight_decay = 10 ** np.random.uniform(-8, -4)
lr = 10 ** np.random.uniform(-6, -2)
# Out:
# 3.560765127880544e-08

# %%
# hyperparameter_optimization.py

# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.util import shuffle_dataset
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 결과를 빠르게 얻기 위해 훈련 데이터를 줄임
x_train = x_train[:500]
t_train = t_train[:500]

# 20%를 검증 데이터로 분할
validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)
x_train, t_train = shuffle_dataset(x_train, t_train)
x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]


def __train(lr, weight_decay, epocs=50):
    network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                            output_size=10, weight_decay_lambda=weight_decay)
    trainer = Trainer(network, x_train, t_train, x_val, t_val,
                      epochs=epocs, mini_batch_size=100,
                      optimizer='sgd', optimizer_param={'lr': lr}, verbose=False)
    trainer.train()

    return trainer.test_acc_list, trainer.train_acc_list


# 하이퍼파라미터 무작위 탐색======================================
optimization_trial = 100
results_val = {}
results_train = {}
for _ in range(optimization_trial):
    # 탐색한 하이퍼파라미터의 범위 지정===============
    weight_decay = 10 ** np.random.uniform(-8, -4)
    lr = 10 ** np.random.uniform(-6, -2)
    # ================================================

    val_acc_list, train_acc_list = __train(lr, weight_decay)
    print("val acc:" + str(val_acc_list[-1]) + " | lr:" + str(lr) + ", weight decay:" + str(weight_decay))
    key = "lr:" + str(lr) + ", weight decay:" + str(weight_decay)
    results_val[key] = val_acc_list
    results_train[key] = train_acc_list

# 그래프 그리기========================================================
print("=========== Hyper-Parameter Optimization Result ===========")
graph_draw_num = 20
col_num = 5
row_num = int(np.ceil(graph_draw_num / col_num))
i = 0

for key, val_acc_list in sorted(results_val.items(), key=lambda x:x[1][-1], reverse=True):
    print("Best-" + str(i+1) + "(val acc:" + str(val_acc_list[-1]) + ") | " + key)

    plt.subplot(row_num, col_num, i+1)
    plt.title("Best-" + str(i+1))
    plt.ylim(0.0, 1.0)
    if i % 5: plt.yticks([])
    plt.xticks([])
    x = np.arange(len(val_acc_list))
    plt.plot(x, val_acc_list)
    plt.plot(x, results_train[key], "--")
    i += 1

    if i >= graph_draw_num:
        break

plt.show()
# Out:
# val acc:0.11 | lr:2.274404907007549e-06, weight decay:2.5481352974922306e-06
# val acc:0.09 | lr:0.00014069058653624534, weight decay:4.3566850666700355e-08
# val acc:0.04 | lr:3.5089712418241986e-06, weight decay:1.8159843658008266e-08
# val acc:0.14 | lr:4.0225284088730305e-05, weight decay:5.013922714817435e-06
# val acc:0.2 | lr:0.00032569187329374366, weight decay:1.6655549925524645e-06
# val acc:0.05 | lr:5.620378530592218e-05, weight decay:1.4626374509184408e-08
# val acc:0.15 | lr:0.0012326173552284663, weight decay:1.8809128000209066e-06
# val acc:0.13 | lr:3.5169361602500264e-05, weight decay:4.267607581566694e-06
# val acc:0.11 | lr:0.0007678684125845765, weight decay:1.318294595327473e-07
# val acc:0.05 | lr:1.2546112959359257e-06, weight decay:1.7471880473190477e-05
# val acc:0.08 | lr:0.0001398964726042385, weight decay:5.148025397696322e-07
# val acc:0.13 | lr:4.066906136939025e-05, weight decay:1.0729078676579581e-05
# val acc:0.11 | lr:8.293783716765757e-06, weight decay:9.79466585859473e-05
# val acc:0.09 | lr:2.3186712836108603e-06, weight decay:7.346317309703119e-07
# val acc:0.1 | lr:1.43107290377461e-06, weight decay:3.147440395330131e-08
# val acc:0.13 | lr:0.00035639230584588077, weight decay:7.860688420295011e-05
# val acc:0.14 | lr:3.7054490406232402e-06, weight decay:3.468869412027099e-05
# val acc:0.08 | lr:4.138638960553318e-06, weight decay:6.040394323941247e-06
# val acc:0.72 | lr:0.00817923567200386, weight decay:1.4244965950228468e-05
# val acc:0.14 | lr:1.7574990461535046e-06, weight decay:6.375141422398044e-05
# val acc:0.72 | lr:0.004748866213348234, weight decay:3.0217733329646504e-05
# val acc:0.43 | lr:0.0027857587342477886, weight decay:2.198648056634777e-08
# val acc:0.12 | lr:3.203113328001365e-05, weight decay:6.0920216485258525e-05
# val acc:0.06 | lr:3.6850334796849556e-06, weight decay:1.6693972948472805e-06
# val acc:0.24 | lr:0.0008302663570274479, weight decay:1.6711588826768285e-05
# val acc:0.04 | lr:0.0005146243955457135, weight decay:7.287993787251756e-06
# val acc:0.77 | lr:0.008895382054714338, weight decay:2.7112540761331805e-05
# val acc:0.33 | lr:0.0011895395688605226, weight decay:9.13955461704614e-08
# val acc:0.06 | lr:6.233762191412044e-06, weight decay:9.666121332755807e-07
# val acc:0.05 | lr:7.862342915186953e-05, weight decay:2.0069889261868876e-08
# val acc:0.18 | lr:0.0005580513461466778, weight decay:5.867921215332474e-06
# val acc:0.09 | lr:7.863937831397592e-05, weight decay:8.343377868235007e-05
# val acc:0.13 | lr:0.0001328047427041076, weight decay:3.0363653951544283e-06
# val acc:0.12 | lr:1.4323239829070783e-06, weight decay:6.806181362079451e-06
# val acc:0.08 | lr:1.804344921468179e-06, weight decay:4.0923290110718726e-07
# val acc:0.53 | lr:0.004658269802374693, weight decay:1.694928210428351e-07
# val acc:0.04 | lr:4.426567991479253e-06, weight decay:8.143814179205368e-07
# val acc:0.1 | lr:1.6634962776035962e-05, weight decay:7.487278088082937e-06
# val acc:0.17 | lr:0.00022152930833714844, weight decay:6.128034091850031e-05
# val acc:0.66 | lr:0.0064578980113831905, weight decay:3.7160224707875235e-05
# val acc:0.1 | lr:0.00014719645206110097, weight decay:5.996246479670032e-05
# val acc:0.12 | lr:2.133022389197702e-05, weight decay:2.9970557833505173e-06
# val acc:0.17 | lr:0.00040269141434843983, weight decay:1.4473625879747868e-07
# val acc:0.16 | lr:0.00026889217591756964, weight decay:3.7664875222637024e-07
# val acc:0.17 | lr:0.0010292878133540415, weight decay:8.746875356272751e-05
# val acc:0.06 | lr:1.5439104329978155e-05, weight decay:1.5392557215145307e-07
# val acc:0.07 | lr:0.00010583119352607652, weight decay:3.2452415892941185e-06
# val acc:0.15 | lr:0.0003238119171607127, weight decay:1.9639420624179848e-05
# val acc:0.13 | lr:1.8551885825502105e-05, weight decay:9.532098371292393e-05
# val acc:0.16 | lr:0.00037916090240709097, weight decay:1.028939295510338e-07
# val acc:0.11 | lr:0.00019663122729227515, weight decay:1.002534878277284e-07
# val acc:0.33 | lr:0.0018546329635328285, weight decay:4.1305899157738776e-05
# val acc:0.07 | lr:4.1756634422534965e-05, weight decay:1.5229342073653843e-06
# val acc:0.06 | lr:9.894186797143806e-05, weight decay:2.490922439132312e-06
# val acc:0.16 | lr:0.0003562109090244406, weight decay:2.618189195872341e-07
# val acc:0.11 | lr:0.00014155045758530222, weight decay:4.696175382622895e-08
# val acc:0.71 | lr:0.00718743710382295, weight decay:7.662950581007134e-08
# val acc:0.65 | lr:0.005871391543681518, weight decay:1.9379449961188835e-07
# val acc:0.13 | lr:6.564416143558684e-06, weight decay:7.834646803486858e-08
# val acc:0.33 | lr:0.0028844573357093687, weight decay:1.4959699055955723e-06
# val acc:0.1 | lr:3.2765414992701046e-06, weight decay:6.987482345961844e-08
# val acc:0.11 | lr:1.7836959541265077e-06, weight decay:2.3769470332171126e-06
# val acc:0.12 | lr:9.068652510670547e-05, weight decay:3.4011655603009217e-06
# val acc:0.13 | lr:0.00019130244009809321, weight decay:1.777774693034935e-05
# val acc:0.03 | lr:3.296097936024332e-05, weight decay:3.7752065168728905e-06
# val acc:0.44 | lr:0.0031060577019299223, weight decay:2.44148335227417e-08
# val acc:0.1 | lr:2.8140321604083342e-05, weight decay:2.5063874111724413e-05
# val acc:0.04 | lr:0.00021941116862677027, weight decay:4.5275934039307186e-07
# val acc:0.21 | lr:0.0011605690217892273, weight decay:4.2692782274466455e-08
# val acc:0.75 | lr:0.009157916734194901, weight decay:1.2185979614832475e-06
# val acc:0.08 | lr:3.4952114117848485e-06, weight decay:2.3691170458707314e-07
# val acc:0.1 | lr:6.524407457254622e-05, weight decay:1.6643740398923686e-05
# val acc:0.06 | lr:5.297147130466404e-05, weight decay:9.399078599423899e-05
# val acc:0.35 | lr:0.0021775715259494334, weight decay:4.355522937626334e-06
# val acc:0.04 | lr:3.690321324230913e-05, weight decay:6.50639496620864e-06
# val acc:0.09 | lr:6.474512787808044e-05, weight decay:4.583908758738146e-06
# val acc:0.15 | lr:1.57373951743356e-05, weight decay:7.025765737587419e-08
# val acc:0.75 | lr:0.008094467998763, weight decay:5.059391367114355e-06
# val acc:0.43 | lr:0.006677937324032818, weight decay:8.895658012185525e-06
# val acc:0.13 | lr:2.0876492063672207e-06, weight decay:3.291470441569411e-07
# val acc:0.25 | lr:0.0006277176669011928, weight decay:3.887504057877852e-05
# val acc:0.74 | lr:0.008666794542727783, weight decay:9.63823654462513e-06
# val acc:0.46 | lr:0.0021072078221698325, weight decay:2.8838973292522927e-08
# val acc:0.07 | lr:5.933364389532234e-06, weight decay:2.0529727645251405e-05
# val acc:0.07 | lr:3.405588950577352e-06, weight decay:2.441970306507773e-07
# val acc:0.11 | lr:0.0004649215452915128, weight decay:2.128418519030586e-08
# val acc:0.04 | lr:2.598727325738577e-05, weight decay:1.854850110632681e-05
# val acc:0.13 | lr:4.012684853579869e-06, weight decay:7.57904841350351e-07
# val acc:0.15 | lr:0.0001632892436508617, weight decay:5.790872638612114e-05
# val acc:0.1 | lr:2.752748222440338e-05, weight decay:2.250937931921716e-07
# val acc:0.11 | lr:5.270257541775605e-05, weight decay:1.9924977408223e-08
# val acc:0.09 | lr:3.142527167039948e-05, weight decay:6.872991515625462e-06
# val acc:0.62 | lr:0.007212648184119919, weight decay:1.69907451268628e-06
# val acc:0.24 | lr:0.0016860606198155536, weight decay:2.6567345225894e-08
# val acc:0.07 | lr:0.00017570604760247207, weight decay:6.58201279399257e-08
# val acc:0.11 | lr:0.0001459795095454677, weight decay:5.796043339666016e-07
# val acc:0.13 | lr:0.00013668883773211275, weight decay:9.777838639186738e-08
# val acc:0.14 | lr:8.676982799085167e-05, weight decay:4.1953212927453856e-05
# val acc:0.2 | lr:0.0012248321618777821, weight decay:1.6250570065833035e-05
# val acc:0.14 | lr:0.000165416066924749, weight decay:4.7036938606517975e-06
# =========== Hyper-Parameter Optimization Result ===========
# Best-1(val acc:0.77) | lr:0.008895382054714338, weight decay:2.7112540761331805e-05
# Best-2(val acc:0.75) | lr:0.009157916734194901, weight decay:1.2185979614832475e-06
# Best-3(val acc:0.75) | lr:0.008094467998763, weight decay:5.059391367114355e-06
# Best-4(val acc:0.74) | lr:0.008666794542727783, weight decay:9.63823654462513e-06
# Best-5(val acc:0.72) | lr:0.00817923567200386, weight decay:1.4244965950228468e-05
# Best-6(val acc:0.72) | lr:0.004748866213348234, weight decay:3.0217733329646504e-05
# Best-7(val acc:0.71) | lr:0.00718743710382295, weight decay:7.662950581007134e-08
# Best-8(val acc:0.66) | lr:0.0064578980113831905, weight decay:3.7160224707875235e-05
# Best-9(val acc:0.65) | lr:0.005871391543681518, weight decay:1.9379449961188835e-07
# Best-10(val acc:0.62) | lr:0.007212648184119919, weight decay:1.69907451268628e-06
# Best-11(val acc:0.53) | lr:0.004658269802374693, weight decay:1.694928210428351e-07
# Best-12(val acc:0.46) | lr:0.0021072078221698325, weight decay:2.8838973292522927e-08
# Best-13(val acc:0.44) | lr:0.0031060577019299223, weight decay:2.44148335227417e-08
# Best-14(val acc:0.43) | lr:0.0027857587342477886, weight decay:2.198648056634777e-08
# Best-15(val acc:0.43) | lr:0.006677937324032818, weight decay:8.895658012185525e-06
# Best-16(val acc:0.35) | lr:0.0021775715259494334, weight decay:4.355522937626334e-06
# Best-17(val acc:0.33) | lr:0.0011895395688605226, weight decay:9.13955461704614e-08
# Best-18(val acc:0.33) | lr:0.0018546329635328285, weight decay:4.1305899157738776e-05
# Best-19(val acc:0.33) | lr:0.0028844573357093687, weight decay:1.4959699055955723e-06
# Best-20(val acc:0.25) | lr:0.0006277176669011928, weight decay:3.887504057877852e-05
